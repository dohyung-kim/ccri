# %%
import ee
import geemap
import pandas as pd
import os
import json
import geopandas as gpd
import geemap
import time

# Initialize
ee.Authenticate()
ee.Initialize(project='unicef-ccri')

# %% [markdown]
# ADM0

# %%
# Define admin level
admin_level = 'adm0'

# Set output folder
output_folder = f'p1_exposure_{admin_level}'
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Load child population and replace one image
org_childpop = ee.ImageCollection("projects/unicef-ccri/assets/WorldPop_Con_T_U18")
childpop = org_childpop.mosaic()
scale = org_childpop.first().projection().nominalScale()
totalpop = ee.Image("projects/unicef-ccri/assets/worldpop_1km")
totalpop_res = totalpop.projection().nominalScale()

reference_image = ee.Image("projects/unicef-ccri/assets/heatwave_frequency_2014_2023_avg")
target_scale = reference_image.projection().nominalScale()
target_crs = reference_image.projection().crs()

# Hazard list
hazards = [
    {"id": "projects/unicef-ccri/assets/river_flood_r100", "threshold": 0.01, "name": "river_flood_100yr_jrc_2024"},
    {"id": "projects/unicef-ccri/assets/coastal_flood_r100", "threshold": 0, "name": "coastal_flood_100yr_jrc_2024"},
    {"id": "projects/unicef-ccri/assets/storm_giri_rp100", "threshold": 17.5, "name": "tropical_storm_100yr_giri_2024"},
    {"id": "projects/unicef-ccri/assets/ASI_return_level_100yr", "threshold": 30, "name": "agricultural_drought_fao_1984-2023"},
    {"id": "projects/unicef-ccri/assets/drought_spei_copernicus_1940_2024", "threshold": -1.5, "name": "drought_spei_copernicus_1940-2024"},
    {"id": "projects/unicef-ccri/assets/drought_spi_copernicus_1940_2024", "threshold": -1.5, "name": "drought_spi_copernicus_1940-2024"},
    {"id": "projects/unicef-ccri/assets/heatwave_frequency_return_level_100yr", "threshold": 'Mean', "name": "heatwave_frequency_ecmwf_2014-2024"},
    {"id": "projects/unicef-ccri/assets/heatwave_duration_return_level_100yr", "threshold": 'Mean', "name": "heatwave_duration_ecmwf_2014-2024"},
    {"id": "projects/unicef-ccri/assets/heatwave_severity_return_level_100yr", "threshold": 'Mean', "name": "heatwave_severity_ecmwf_2014-2024"},
    {"id": "projects/unicef-ccri/assets/high_temp_degree_days_return_level_100yr", "threshold": 35, "name": "extreme_heat_ecmwf_2014-2024"},
    {"id": "projects/unicef-ccri/assets/FIRMS_FRP_90th_percentile", "threshold": 'Mean', "name": "fire_FRP_nasa_2001-2024"},
    {"id": "projects/unicef-ccri/assets/FIRMS_count_90th_percentile", "threshold": 'Mean', "name": "fire_frequency_nasa_2001-2023"},
    {"id": "projects/unicef-ccri/assets/sand_dust_storm_annual", "threshold": 0, "name": "sand_dust_storm_unccd_2024"},
    {"id": "projects/unicef-ccri/assets/pm25_p90_1998_2023", "threshold": 5, "name": "air_pollution_pm25_1998-2023"},
    {"id": "projects/unicef-ccri/assets/Pv_average_2013_2022", "threshold": 0.001, "name": "vectorborne_malariapv_2012-2022"},
    {"id": "projects/unicef-ccri/assets/Pf_average_2013_2022", "threshold": 0.001, "name": "vectorborne_malariapf_2012-2022"}
]

# Load country boundaries
admin_fc_path = f'projects/unicef-ccri/assets/georepo_{admin_level}'
country_fc = ee.FeatureCollection(admin_fc_path)
simple_fc = ee.FeatureCollection(f'projects/unicef-ccri/assets/{admin_level}_simple')
area_fc = ee.FeatureCollection(f'projects/unicef-ccri/assets/{admin_level}_wfp')
adm_ids = country_fc.aggregate_array('WFP_ID').distinct().getInfo()
global_geom = simple_fc.geometry()

# Group features by 'WFP_ID' and merge geometries
merged_fc = country_fc.distinct(['WFP_ID']).map(lambda f: f.setGeometry(
      country_fc
        .filter(ee.Filter.eq('WFP_ID', f.get('WFP_ID')))
        .geometry()
        .dissolve()
  ))


# Update thresholds if needed
for hazard in hazards:
    if hazard['threshold'] == 'Mean':
        layer = (
            ee.ImageCollection(hazard['id']).mosaic()
            if hazard['name'] in ["river_flood_100yr_jrc_2024", "coastal_flood_100yr_jrc_2024", "tropical_storm_100yr_giri_2024"]
            else ee.Image(hazard['id'])
        )
        th = layer.reduceRegion(
            reducer=ee.Reducer.mean(),
            geometry=global_geom,
            scale=target_scale,
            bestEffort=True,
            maxPixels=1e13
        ).values().get(0)
        if th is not None:
            hazard['threshold'] = ee.Number(th).getInfo()
        else:
            print(f"⚠️ Skipping hazard {hazard['name']} — global mean threshold is null.")
            hazard['skip'] = True


th_shape_area = area_fc.filter(ee.Filter.eq('iso3', 'ITA')).first().getNumber('Shape_Area')

# Loop through admin regions
for adm_id in adm_ids:
    print(adm_id)
    if adm_id is None:
        continue

    # Filter feature by adm_id
    region = merged_fc.filter(ee.Filter.eq('WFP_ID', adm_id)).first()
    area_region = area_fc.filter(ee.Filter.eq('adm0_id', int(adm_id))).first()

    print(f"Submitting task for {admin_level}_id: {adm_id}...")

    shape_area = area_region.getNumber('Shape_Area')

    # Choose simplification level based on area
    simplification_tolerance = ee.Algorithms.If(
        shape_area.gt(th_shape_area),
        10000,
        100
    )

    simplified_geom = region.geometry().simplify(simplification_tolerance)
    region_geom = ee.Geometry(simplified_geom)

    iso3 = region.get('ISO3')
    wfp_id = region.get('WFP_ID')
    region_name = region.get(f'name')
    region_type = region.get(f'type')

    childpop_sum = childpop.reduceRegion(
        ee.Reducer.sum(), region_geom, scale=scale, crs='EPSG:4326', maxPixels=1e13).get('b1')
    totalpop_sum = totalpop.reduceRegion(
        ee.Reducer.sum(), region_geom, scale=totalpop_res, crs='EPSG:4326', maxPixels=1e13).get('b1')

    features = []

    for hazard in hazards:
        if hazard.get('skip'):
            continue
        name = hazard['name']
        TH = hazard['threshold']

        layer = (
            ee.ImageCollection(hazard['id']).mosaic()
            if hazard['name'] in ["river_flood_100yr_jrc_2024", "coastal_flood_100yr_jrc_2024", "tropical_storm_100yr_giri_2024"]
            else ee.Image(hazard['id'])
        )

        if name == "agricultural_drought_fao_1984-2023":
            layer = layer.updateMask(layer.lte(100))
            exposed = childpop.updateMask(layer.gt(ee.Image.constant(TH)))
        elif name in ["drought_spei_copernicus_1940-2024", "drought_spi_copernicus_1940-2024"]:
            exposed = childpop.updateMask(layer.lt(ee.Image.constant(TH)))
        else:
            exposed = childpop.updateMask(layer.gt(ee.Image.constant(TH)))


        if name == "coastal_flood_100yr_jrc_2024":
              region_geom = region_geom.buffer(5000) #buffer 5km for coastal flood
        else:
              region_geom = ee.Geometry(simplified_geom)


        exposed_sum = exposed.reduceRegion(
            ee.Reducer.sum(), region_geom, scale=scale, bestEffort=True, crs='EPSG:4326', maxPixels=1e13).get('b1')

        feature = ee.Feature(None, {

            'iso3': iso3,
            'wfp_id': wfp_id,
            f'{admin_level}_name': region_name,
            'type' : region_type,
            'hazard': name,
            'child_population_exposed': exposed_sum,
            'child_population_total': childpop_sum,
            'population_total': totalpop_sum
        })
        features.append(feature)

    task = ee.batch.Export.table.toDrive(
        collection=ee.FeatureCollection(features),
        description=f"{adm_id}_hazards_{admin_level}",
        folder=output_folder,
        fileFormat='CSV',
        selectors=[
            'iso3', 'wfp_id', f'{admin_level}_name', 'type', 'hazard',
            'child_population_exposed', 'child_population_total', 'population_total'
        ]
    )
    task.start()


print("✅ All tasks submitted.")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 9
# Submitting task for adm0_id: 9...
# 268
# Submitting task for adm0_id: 268...
# 87
# Submitting task for adm0_id: 87...
# 55
# Submitting task for adm0_id: 55...
# 178
# Submitting task for adm0_id: 178...
# 30
# Submitting task for adm0_id: 30...
# 95
# Submitting task for adm0_id: 95...
# 39
# Submitting task for adm0_id: 39...
# 48
# Submitting task for adm0_id: 48...
# 168
# Submitting task for adm0_id: 168...
# 197
# Submitting task for adm0_id: 197...
# 207
# Submitting task for adm0_id: 207...
# 1017
# Submitting task for adm0_id: 1017...
# 1019
# Submitting task for adm0_id: 1019...
# 1018
# Submitting task for adm0_id: 1018...
# 244
# Submitting task for adm0_id: 244...
# 251
# Submitting task for adm0_id: 251...
# 5
# Submitting task for adm0_id: 5...
# 101
# Submitting task for adm0_id: 101...
# 258
# Submitting task for adm0_id: 258...
# 98
# Submitting task for adm0_id: 98...
# 283
# Submitting task for adm0_id: 283...
# 15
# Submitting task for adm0_id: 15...
# 218
# Submitting task for adm0_id: 218...
# 136
# Submitting task for adm0_id: 136...
# 282
# Submitting task for adm0_id: 282...
# 286
# Submitting task for adm0_id: 286...
# 102
# Submitting task for adm0_id: 102...
# 2
# Submitting task for adm0_id: 2...
# 285
# Submitting task for adm0_id: 285...
# 1014
# Submitting task for adm0_id: 1014...
# 193
# Submitting task for adm0_id: 193...
# 230
# Submitting task for adm0_id: 230...
# 216
# Submitting task for adm0_id: 216...
# 52
# Submitting task for adm0_id: 52...
# 149
# Submitting task for adm0_id: 149...
# 281
# Submitting task for adm0_id: 281...
# 288
# Submitting task for adm0_id: 288...
# 1
# Submitting task for adm0_id: 1...
# 8
# Submitting task for adm0_id: 8...
# 3
# Submitting task for adm0_id: 3...
# 7
# Submitting task for adm0_id: 7...
# 255
# Submitting task for adm0_id: 255...
# 12
# Submitting task for adm0_id: 12...
# 13
# Submitting task for adm0_id: 13...
# 11
# Submitting task for adm0_id: 11...
# 17
# Submitting task for adm0_id: 17...
# 18
# Submitting task for adm0_id: 18...
# 19
# Submitting task for adm0_id: 19...
# 43
# Submitting task for adm0_id: 43...
# 27
# Submitting task for adm0_id: 27...
# 29
# Submitting task for adm0_id: 29...
# 42
# Submitting task for adm0_id: 42...
# 23
# Submitting task for adm0_id: 23...
# 41
# Submitting task for adm0_id: 41...
# 21
# Submitting task for adm0_id: 21...
# 20
# Submitting task for adm0_id: 20...
# 34
# Submitting task for adm0_id: 34...
# 26
# Submitting task for adm0_id: 26...
# 28
# Submitting task for adm0_id: 28...
# 33
# Submitting task for adm0_id: 33...
# 37
# Submitting task for adm0_id: 37...
# 24
# Submitting task for adm0_id: 24...
# 40
# Submitting task for adm0_id: 40...
# 31
# Submitting task for adm0_id: 31...
# 35
# Submitting task for adm0_id: 35...
# 49
# Submitting task for adm0_id: 49...
# 46
# Submitting task for adm0_id: 46...
# 237
# Submitting task for adm0_id: 237...
# 51
# Submitting task for adm0_id: 51...
# 53
# Submitting task for adm0_id: 53...
# 66
# Submitting task for adm0_id: 66...
# 45
# Submitting task for adm0_id: 45...
# 68
# Submitting task for adm0_id: 68...
# 59
# Submitting task for adm0_id: 59...
# 57
# Submitting task for adm0_id: 57...
# 58
# Submitting task for adm0_id: 58...
# 47
# Submitting task for adm0_id: 47...
# 61
# Submitting task for adm0_id: 61...
# 279
# Submitting task for adm0_id: 279...
# 64
# Submitting task for adm0_id: 64...
# 65
# Submitting task for adm0_id: 65...
# 93
# Submitting task for adm0_id: 93...
# 70
# Submitting task for adm0_id: 70...
# 289
# Submitting task for adm0_id: 289...
# 69
# Submitting task for adm0_id: 69...
# 72
# Submitting task for adm0_id: 72...
# 4
# Submitting task for adm0_id: 4...
# 73
# Submitting task for adm0_id: 73...
# 284
# Submitting task for adm0_id: 284...
# 77
# Submitting task for adm0_id: 77...
# 229
# Submitting task for adm0_id: 229...
# 78
# Submitting task for adm0_id: 78...
# 79
# Submitting task for adm0_id: 79...
# 84
# Submitting task for adm0_id: 84...
# 276
# Submitting task for adm0_id: 276...
# 85
# Submitting task for adm0_id: 85...
# 163
# Submitting task for adm0_id: 163...
# 89
# Submitting task for adm0_id: 89...
# 256
# Submitting task for adm0_id: 256...
# 92
# Submitting task for adm0_id: 92...
# 94
# Submitting task for adm0_id: 94...
# 106
# Submitting task for adm0_id: 106...
# 90
# Submitting task for adm0_id: 90...
# 105
# Submitting task for adm0_id: 105...
# 76
# Submitting task for adm0_id: 76...
# 97
# Submitting task for adm0_id: 97...
# 99
# Submitting task for adm0_id: 99...
# 103
# Submitting task for adm0_id: 103...
# 107
# Submitting task for adm0_id: 107...
# 111
# Submitting task for adm0_id: 111...
# 62
# Submitting task for adm0_id: 62...
# 108
# Submitting task for adm0_id: 108...
# 113
# Submitting task for adm0_id: 113...
# 272
# Submitting task for adm0_id: 272...
# 115
# Submitting task for adm0_id: 115...
# 119
# Submitting task for adm0_id: 119...
# 117
# Submitting task for adm0_id: 117...
# 118
# Submitting task for adm0_id: 118...
# 114
# Submitting task for adm0_id: 114...
# 121
# Submitting task for adm0_id: 121...
# 122
# Submitting task for adm0_id: 122...
# 123
# Submitting task for adm0_id: 123...
# 130
# Submitting task for adm0_id: 130...
# 126
# Submitting task for adm0_id: 126...
# 132
# Submitting task for adm0_id: 132...
# 133
# Submitting task for adm0_id: 133...
# 138
# Submitting task for adm0_id: 138...
# 44
# Submitting task for adm0_id: 44...
# 135
# Submitting task for adm0_id: 135...
# 208
# Submitting task for adm0_id: 208...
# 202
# Submitting task for adm0_id: 202...
# 137
# Submitting task for adm0_id: 137...
# 139
# Submitting task for adm0_id: 139...
# 141
# Submitting task for adm0_id: 141...
# 144
# Submitting task for adm0_id: 144...
# 145
# Submitting task for adm0_id: 145...
# 209
# Submitting task for adm0_id: 209...
# 146
# Submitting task for adm0_id: 146...
# 231
# Submitting task for adm0_id: 231...
# 142
# Submitting task for adm0_id: 142...
# 147
# Submitting task for adm0_id: 147...
# 148
# Submitting task for adm0_id: 148...
# 140
# Submitting task for adm0_id: 140...
# 169
# Submitting task for adm0_id: 169...
# 166
# Submitting task for adm0_id: 166...
# 165
# Submitting task for adm0_id: 165...
# 150
# Submitting task for adm0_id: 150...
# 154
# Submitting task for adm0_id: 154...
# 162
# Submitting task for adm0_id: 162...
# 157
# Submitting task for adm0_id: 157...
# 241
# Submitting task for adm0_id: 241...
# 155
# Submitting task for adm0_id: 155...
# 156
# Submitting task for adm0_id: 156...
# 273
# Submitting task for adm0_id: 273...
# 2647
# Submitting task for adm0_id: 2647...
# 167
# Submitting task for adm0_id: 167...
# 170
# Submitting task for adm0_id: 170...
# 159
# Submitting task for adm0_id: 159...
# 160
# Submitting task for adm0_id: 160...
# 152
# Submitting task for adm0_id: 152...
# 153
# Submitting task for adm0_id: 153...
# 172
# Submitting task for adm0_id: 172...
# 181
# Submitting task for adm0_id: 181...
# 182
# Submitting task for adm0_id: 182...
# 180
# Submitting task for adm0_id: 180...
# 177
# Submitting task for adm0_id: 177...
# 186
# Submitting task for adm0_id: 186...
# 175
# Submitting task for adm0_id: 175...
# 173
# Submitting task for adm0_id: 173...
# 179
# Submitting task for adm0_id: 179...
# 187
# Submitting task for adm0_id: 187...
# 188
# Submitting task for adm0_id: 188...
# 191
# Submitting task for adm0_id: 191...
# 195
# Submitting task for adm0_id: 195...
# 275
# Submitting task for adm0_id: 275...
# 189
# Submitting task for adm0_id: 189...
# 274
# Submitting task for adm0_id: 274...
# 198
# Submitting task for adm0_id: 198...
# 67
# Submitting task for adm0_id: 67...
# 199
# Submitting task for adm0_id: 199...
# 194
# Submitting task for adm0_id: 194...
# 3000
# Submitting task for adm0_id: 3000...
# 201
# Submitting task for adm0_id: 201...
# 203
# Submitting task for adm0_id: 203...
# 204
# Submitting task for adm0_id: 204...
# 205
# Submitting task for adm0_id: 205...
# 215
# Submitting task for adm0_id: 215...
# 280
# Submitting task for adm0_id: 280...
# 278
# Submitting task for adm0_id: 278...
# 222
# Submitting task for adm0_id: 222...
# 225
# Submitting task for adm0_id: 225...
# 221
# Submitting task for adm0_id: 221...
# 75
# Submitting task for adm0_id: 75...
# 213
# Submitting task for adm0_id: 213...
# 226
# Submitting task for adm0_id: 226...
# 2648
# Submitting task for adm0_id: 2648...
# 287
# Submitting task for adm0_id: 287...
# 214
# Submitting task for adm0_id: 214...
# 233
# Submitting task for adm0_id: 233...
# 223
# Submitting task for adm0_id: 223...
# 224
# Submitting task for adm0_id: 224...
# 236
# Submitting task for adm0_id: 236...
# 235
# Submitting task for adm0_id: 235...
# 220
# Submitting task for adm0_id: 220...
# 238
# Submitting task for adm0_id: 238...
# 50
# Submitting task for adm0_id: 50...
# 243
# Submitting task for adm0_id: 243...
# 240
# Submitting task for adm0_id: 240...
# 239
# Submitting task for adm0_id: 239...
# 250
# Submitting task for adm0_id: 250...
# 242
# Submitting task for adm0_id: 242...
# 245
# Submitting task for adm0_id: 245...
# 246
# Submitting task for adm0_id: 246...
# 248
# Submitting task for adm0_id: 248...
# 249
# Submitting task for adm0_id: 249...
# 252
# Submitting task for adm0_id: 252...
# 257
# Submitting task for adm0_id: 257...
# 253
# Submitting task for adm0_id: 253...
# 254
# Submitting task for adm0_id: 254...
# 260
# Submitting task for adm0_id: 260...
# 259
# Submitting task for adm0_id: 259...
# 261
# Submitting task for adm0_id: 261...
# 110
# Submitting task for adm0_id: 110...
# 211
# Submitting task for adm0_id: 211...
# 263
# Submitting task for adm0_id: 263...
# 264
# Submitting task for adm0_id: 264...
# 277
# Submitting task for adm0_id: 277...
# 212
# Submitting task for adm0_id: 212...
# 269
# Submitting task for adm0_id: 269...
# 227
# Submitting task for adm0_id: 227...
# 270
# Submitting task for adm0_id: 270...
# 271
# Submitting task for adm0_id: 271...
# 16
# Submitting task for adm0_id: 16...
# 54
# Submitting task for adm0_id: 54...
# 56
# Submitting task for adm0_id: 56...
# 184
# Submitting task for adm0_id: 184...
# 82
# Submitting task for adm0_id: 82...
# 1006
# Submitting task for adm0_id: 1006...
# 1000
# Submitting task for adm0_id: 1000...
# 25
# Submitting task for adm0_id: 25...
# 86
# Submitting task for adm0_id: 86...
# 88
# Submitting task for adm0_id: 88...
# 80
# Submitting task for adm0_id: 80...
# 100
# Submitting task for adm0_id: 100...
# 131
# Submitting task for adm0_id: 131...
# 158
# Submitting task for adm0_id: 158...
# 1004
# Submitting task for adm0_id: 1004...
# 161
# Submitting task for adm0_id: 161...
# 206
# Submitting task for adm0_id: 206...
# 210
# Submitting task for adm0_id: 210...
# 247
# Submitting task for adm0_id: 247...
# 266
# Submitting task for adm0_id: 266...
# 1007
# Submitting task for adm0_id: 1007...
# 1013
# Submitting task for adm0_id: 1013...
# 38
# Submitting task for adm0_id: 38...
# 104
# Submitting task for adm0_id: 104...
# 120
# Submitting task for adm0_id: 120...
# 128
# Submitting task for adm0_id: 128...
# 1015
# Submitting task for adm0_id: 1015...
# 1016
# Submitting task for adm0_id: 1016...
# 14
# Submitting task for adm0_id: 14...
# 1005
# Submitting task for adm0_id: 1005...
# 1001
# Submitting task for adm0_id: 1001...
# 1002
# Submitting task for adm0_id: 1002...
# 1003
# Submitting task for adm0_id: 1003...
# 1012
# Submitting task for adm0_id: 1012...
# 234
# Submitting task for adm0_id: 234...
# 60
# Submitting task for adm0_id: 60...
# 183
# Submitting task for adm0_id: 183...
# 1008
# Submitting task for adm0_id: 1008...
# 1009
# Submitting task for adm0_id: 1009...
# 22
# Submitting task for adm0_id: 22...
# 265
# Submitting task for adm0_id: 265...
# 112
# Submitting task for adm0_id: 112...
# 127
# Submitting task for adm0_id: 127...
# 129
# Submitting task for adm0_id: 129...
# 134
# Submitting task for adm0_id: 134...
# 164
# Submitting task for adm0_id: 164...
# 190
# Submitting task for adm0_id: 190...
# 174
# Submitting task for adm0_id: 174...
# 185
# Submitting task for adm0_id: 185...
# 200
# Submitting task for adm0_id: 200...
# 32
# Submitting task for adm0_id: 32...
# 10
# Submitting task for adm0_id: 10...
# 109
# Submitting task for adm0_id: 109...
# 81
# Submitting task for adm0_id: 81...
# 228
# Submitting task for adm0_id: 228...
# 36
# Submitting task for adm0_id: 36...
# ✅ All tasks submitted.

# %% [markdown]
# ADM1

# %%
# Load child population and replace one image
org_childpop = ee.ImageCollection("projects/unicef-ccri/assets/childpop_constrained")
image_to_replace_id = 'tha_T_Under_18_2024_CN_100m_R2024A_v1'
new_image = ee.Image(f'projects/unicef-ccri/assets/{image_to_replace_id}').set('system:index', image_to_replace_id)
filtered_collection = org_childpop.filter(ee.Filter.neq('system:index', image_to_replace_id))
childpop = filtered_collection.merge(ee.ImageCollection([new_image])).mosaic()
scale = filtered_collection.first().projection().nominalScale()
totalpop = ee.Image("projects/unicef-ccri/assets/worldpop_1km")
totalpop_res = totalpop.projection().nominalScale()

reference_image = ee.Image("projects/unicef-ccri/assets/heatwave_frequency_2014_2023_avg")
target_scale = reference_image.projection().nominalScale()
target_crs = reference_image.projection().crs()

# Hazard list
hazards = [
    {"id": "projects/unicef-ccri/assets/river_flood_r100", "threshold": 0.01, "name": "river_flood_100yr_jrc_2024"},
    {"id": "projects/unicef-ccri/assets/coastal_flood_r100", "threshold": 0, "name": "coastal_flood_100yr_jrc_2024"},
    {"id": "projects/unicef-ccri/assets/storm_giri_rp100", "threshold": 17.5, "name": "tropical_storm_100yr_giri_2024"},
    {"id": "projects/unicef-ccri/assets/ASI_return_level_100yr", "threshold": 30, "name": "agricultural_drought_fao_1984-2023"},
    {"id": "projects/unicef-ccri/assets/drought_spei_copernicus_1940_2024", "threshold": -1.5, "name": "drought_spei_copernicus_1940-2024"},
    {"id": "projects/unicef-ccri/assets/drought_spi_copernicus_1940_2024", "threshold": -1.5, "name": "drought_spi_copernicus_1940-2024"},
    {"id": "projects/unicef-ccri/assets/heatwave_frequency_return_level_100yr", "threshold": 'Mean', "name": "heatwave_frequency_ecmwf_2014-2024"},
    {"id": "projects/unicef-ccri/assets/heatwave_duration_return_level_100yr", "threshold": 'Mean', "name": "heatwave_duration_ecmwf_2014-2024"},
    {"id": "projects/unicef-ccri/assets/heatwave_severity_return_level_100yr", "threshold": 'Mean', "name": "heatwave_severity_ecmwf_2014-2024"},
    {"id": "projects/unicef-ccri/assets/high_temp_degree_days_return_level_100yr", "threshold": 35, "name": "extreme_heat_ecmwf_2014-2024"},
    {"id": "projects/unicef-ccri/assets/FIRMS_FRP_90th_percentile", "threshold": 'Mean', "name": "fire_FRP_nasa_2001-2024"},
    {"id": "projects/unicef-ccri/assets/FIRMS_count_90th_percentile", "threshold": 'Mean', "name": "fire_frequency_nasa_2001-2023"},
    {"id": "projects/unicef-ccri/assets/sand_dust_storm_annual", "threshold": 0, "name": "sand_dust_storm_unccd_2024"},
    {"id": "projects/unicef-ccri/assets/pm25_p90_1998_2023", "threshold": 5, "name": "air_pollution_pm25_1998-2023"},
    {"id": "projects/unicef-ccri/assets/Pv_average_2013_2022", "threshold": 0.001, "name": "vectorborne_malariapv_2012-2022"},
    {"id": "projects/unicef-ccri/assets/Pf_average_2013_2022", "threshold": 0.001, "name": "vectorborne_malariapf_2012-2022"}
]

# Load country boundaries

GAUL_fc_path = f'projects/sat-io/open-datasets/FAO/GAUL/GAUL_2024_L{admin_level}'
WFP_fc_path = f'projects/unicef-ccri/assets/adm0_wfp'

# Load FeatureCollections
gaul_fc = ee.FeatureCollection(GAUL_fc_path)
wfp_fc = ee.FeatureCollection(WFP_fc_path)

# Define spatial join
spatial_filter = ee.Filter.intersects(leftField='.geo', rightField='.geo')
save_all_join = ee.Join.saveAll(matchesKey='matched_wfp')

# Apply the join: attach intersecting WFP features to each GAUL feature
joined_fc = save_all_join.apply(primary=gaul_fc, secondary=wfp_fc, condition=spatial_filter)


adm_ids = joined_fc.aggregate_array(f'gaul{admin_level}_code').distinct().getInfo()

simple_fc = ee.FeatureCollection(f'projects/unicef-ccri/assets/adm0_simple')
global_geom = simple_fc.geometry()

# Update thresholds if needed
for hazard in hazards:
    if hazard['threshold'] == 'Mean':
        layer = (
            ee.ImageCollection(hazard['id']).mosaic()
            if hazard['name'] in ["river_flood_100yr_jrc_2024", "coastal_flood_100yr_jrc_2024", "tropical_storm_100yr_giri_2024"]
            else ee.Image(hazard['id'])
        )
        th = layer.reduceRegion(
            reducer=ee.Reducer.mean(),
            geometry=global_geom,
            scale=target_scale,
            bestEffort=True,
            maxPixels=1e13
        ).values().get(0)
        if th is not None:
            hazard['threshold'] = ee.Number(th).getInfo()
        else:
            print(f"⚠️ Skipping hazard {hazard['name']} — global mean threshold is null.")
            hazard['skip'] = True


th_shape_area = wfp_fc.filter(ee.Filter.eq(f'adm0_id', 122)).first().geometry().area()
#thresh = th_shape_area.getInfo()
# Function to compute intersection area for each WFP match
def score_overlap(wfp_feature):
    wfp_geom = ee.Feature(wfp_feature).geometry()
    intersection = region.geometry().intersection(wfp_geom, ee.ErrorMargin(1))
    return ee.Feature(wfp_feature).set('overlap_area', intersection.area())


# Loop through admin regions
for adm_id in adm_ids:
#for i in range(1):  # Loop runs only once
    # adm_id = adm_ids[i]
    print(f"Processing adm_id: {adm_id}...")
    if adm_id is None:
        continue

    # Filter feature by adm_id
    region = joined_fc.filter(ee.Filter.eq(f'gaul{admin_level}_code', adm_id)).first()

    try:
        #region_info = region.getInfo()
        matched_wfp = ee.List(region.get('matched_wfp'))
        # Map over matched WFP features
        scored = ee.FeatureCollection(matched_wfp.map(score_overlap))
        # Get the one with the largest overlap area
        best_matched = scored.sort('overlap_area', False).first()

        #if matched_wfp.size().getInfo() > 0:
        stscod = best_matched.get('stscod')
        wfp_iso3 = best_matched.get('iso3')
        wfp_name = best_matched.get('adm0_name')
    except Exception as e:
        print(f"⚠️ Could not retrieve region for adm_id {adm_id}. Error: {e}")
        stscod = None
        wfp_iso3 = None
        wfp_name = None

    # Skip if stscod is not 'State'
    if stscod in  ['Territory','Non-Self Governing Territory']:
        print(f"Skipping adm_id {adm_id} due to stscod = {stscod}")
        continue

    print(f"Submitting task for {admin_level}_id: {adm_id}...")

    shape_area = region.geometry().area()

    region_geom = ee.Geometry(
        ee.Algorithms.If(
            shape_area.gt(th_shape_area),
            region.geometry().simplify(10000),
            region.geometry()
        )
    )

    #region_geom = region.geometry().simplify(10000)

    iso3 = region.get('iso3_code')
    region_name = region.get('gaul0_name')

    childpop_sum = childpop.reduceRegion(
        ee.Reducer.sum(), region_geom, scale=scale, crs='EPSG:4326', maxPixels=1e13).get('b1')
    totalpop_sum = totalpop.reduceRegion(
        ee.Reducer.sum(), region_geom, scale=totalpop_res, crs='EPSG:4326', maxPixels=1e13).get('b1')

    features = []

    for hazard in hazards:
        if hazard.get('skip'):
            continue
        name = hazard['name']
        TH = hazard['threshold']

        layer = (
            ee.ImageCollection(hazard['id']).mosaic()
            if hazard['name'] in ["river_flood_100yr_jrc_2024", "coastal_flood_100yr_jrc_2024", "tropical_storm_100yr_giri_2024"]
            else ee.Image(hazard['id'])
        )
        ##if the country size is too small resample the hazard layer to the resoulution of population data to prevent zero count
        # if shape_area.lt(th_shape_area):
        #     layer = layer.clip(region_geom).resample('nearest').reproject(crs='EPSG:4326', scale=scale)

        if name == "agricultural_drought_fao_1984-2023":
            layer = layer.updateMask(layer.lte(100))
            exposed = childpop.updateMask(layer.gt(ee.Image.constant(TH)))
        elif name in ["drought_spei_copernicus_1940-2024", "drought_spi_copernicus_1940-2024"]:
            exposed = childpop.updateMask(layer.lt(ee.Image.constant(TH)))
        else:
            exposed = childpop.updateMask(layer.gt(ee.Image.constant(TH)))

        exposed_sum = exposed.reduceRegion(
            ee.Reducer.sum(), region_geom, scale=scale, bestEffort=True, crs='EPSG:4326', maxPixels=1e13).get('b1')

        feature = ee.Feature(None, {
            'gaul0_iso3': iso3,
            'gaul0_name': region_name,
            'gaul1_code': adm_id,
            'wfp_iso3': wfp_iso3,
            'wfp_name': wfp_name,
            'hazard': name,
            'child_population_exposed': exposed_sum,
            'child_population_total': childpop_sum,
            'population_total': totalpop_sum
        })
        features.append(feature)

    task = ee.batch.Export.table.toDrive(
        collection=ee.FeatureCollection(features),
        description=f"adm{adm_id}_hazards_adm{admin_level}",
        folder=output_folder,
        fileFormat='CSV',
        selectors=[
            'gaul0_iso3', 'gaul0_name', 'gaul1_code', 'wfp_iso3', 'wfp_name', 'hazard',
            'child_population_exposed', 'child_population_total', 'population_total'
        ]
    )
    task.start()


print("✅ All tasks submitted.")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Streaming output truncated to the last 5000 lines.
# Submitting task for 1_id: 1611...
# Processing adm_id: 1612...
# Submitting task for 1_id: 1612...
# Processing adm_id: 1613...
# Submitting task for 1_id: 1613...
# Processing adm_id: 1614...
# Submitting task for 1_id: 1614...
# Processing adm_id: 1615...
# Submitting task for 1_id: 1615...
# Processing adm_id: 1616...
# Submitting task for 1_id: 1616...
# Processing adm_id: 1617...
# Submitting task for 1_id: 1617...
# Processing adm_id: 1618...
# Submitting task for 1_id: 1618...
# Processing adm_id: 1619...
# Submitting task for 1_id: 1619...
# Processing adm_id: 1620...
# Submitting task for 1_id: 1620...
# Processing adm_id: 1621...
# Submitting task for 1_id: 1621...
# Processing adm_id: 1622...
# Submitting task for 1_id: 1622...
# Processing adm_id: 1623...
# Submitting task for 1_id: 1623...
# Processing adm_id: 1624...
# Submitting task for 1_id: 1624...
# Processing adm_id: 1625...
# Submitting task for 1_id: 1625...
# Processing adm_id: 1626...
# Submitting task for 1_id: 1626...
# Processing adm_id: 1627...
# Submitting task for 1_id: 1627...
# Processing adm_id: 1628...
# Submitting task for 1_id: 1628...
# Processing adm_id: 2519...
# Submitting task for 1_id: 2519...
# Processing adm_id: 2520...
# Submitting task for 1_id: 2520...
# Processing adm_id: 2521...
# Submitting task for 1_id: 2521...
# Processing adm_id: 2522...
# Submitting task for 1_id: 2522...
# Processing adm_id: 2523...
# Submitting task for 1_id: 2523...
# Processing adm_id: 2524...
# Submitting task for 1_id: 2524...
# Processing adm_id: 2525...
# Submitting task for 1_id: 2525...
# Processing adm_id: 2526...
# Submitting task for 1_id: 2526...
# Processing adm_id: 2527...
# Submitting task for 1_id: 2527...
# Processing adm_id: 2528...
# Submitting task for 1_id: 2528...
# Processing adm_id: 2529...
# Submitting task for 1_id: 2529...
# Processing adm_id: 2531...
# Submitting task for 1_id: 2531...
# Processing adm_id: 2532...
# Submitting task for 1_id: 2532...
# Processing adm_id: 2533...
# Submitting task for 1_id: 2533...
# Processing adm_id: 2534...
# Submitting task for 1_id: 2534...
# Processing adm_id: 2535...
# Submitting task for 1_id: 2535...
# Processing adm_id: 2536...
# Submitting task for 1_id: 2536...
# Processing adm_id: 2537...
# Submitting task for 1_id: 2537...
# Processing adm_id: 2538...
# Submitting task for 1_id: 2538...
# Processing adm_id: 2539...
# Submitting task for 1_id: 2539...
# Processing adm_id: 2542...
# Submitting task for 1_id: 2542...
# Processing adm_id: 2543...
# Submitting task for 1_id: 2543...
# Processing adm_id: 2544...
# Submitting task for 1_id: 2544...
# Processing adm_id: 2546...
# Submitting task for 1_id: 2546...
# Processing adm_id: 2547...
# Submitting task for 1_id: 2547...
# Processing adm_id: 2550...
# Submitting task for 1_id: 2550...
# Processing adm_id: 2551...
# Submitting task for 1_id: 2551...
# Processing adm_id: 2552...
# Submitting task for 1_id: 2552...
# Processing adm_id: 2553...
# Submitting task for 1_id: 2553...
# Processing adm_id: 2554...
# Submitting task for 1_id: 2554...
# Processing adm_id: 2555...
# Submitting task for 1_id: 2555...
# Processing adm_id: 2556...
# Submitting task for 1_id: 2556...
# Processing adm_id: 2557...
# Submitting task for 1_id: 2557...
# Processing adm_id: 2558...
# Submitting task for 1_id: 2558...
# Processing adm_id: 2559...
# Submitting task for 1_id: 2559...
# Processing adm_id: 2560...
# Submitting task for 1_id: 2560...
# Processing adm_id: 2561...
# Submitting task for 1_id: 2561...
# Processing adm_id: 2562...
# Submitting task for 1_id: 2562...
# Processing adm_id: 2563...
# Submitting task for 1_id: 2563...
# Processing adm_id: 2566...
# Submitting task for 1_id: 2566...
# Processing adm_id: 2573...
# Submitting task for 1_id: 2573...
# Processing adm_id: 2575...
# Submitting task for 1_id: 2575...
# Processing adm_id: 2577...
# Submitting task for 1_id: 2577...
# Processing adm_id: 2578...
# Submitting task for 1_id: 2578...
# Processing adm_id: 2579...
# Submitting task for 1_id: 2579...
# Processing adm_id: 2580...
# Submitting task for 1_id: 2580...
# Processing adm_id: 2581...
# Submitting task for 1_id: 2581...
# Processing adm_id: 2582...
# Submitting task for 1_id: 2582...
# Processing adm_id: 2583...
# Submitting task for 1_id: 2583...
# Processing adm_id: 2584...
# Submitting task for 1_id: 2584...
# Submitting task for 1_id: 2391...
# Processing adm_id: 2392...
# Submitting task for 1_id: 2392...
# Processing adm_id: 2393...
# Submitting task for 1_id: 2393...
# Processing adm_id: 2394...
# Submitting task for 1_id: 2394...
# Processing adm_id: 2395...
# Submitting task for 1_id: 2395...
# Processing adm_id: 2396...
# Submitting task for 1_id: 2396...
# Processing adm_id: 2397...
# Submitting task for 1_id: 2397...
# Processing adm_id: 3852...
# Submitting task for 1_id: 3852...
# Processing adm_id: 3853...
# Submitting task for 1_id: 3853...
# Processing adm_id: 3854...
# Submitting task for 1_id: 3854...
# Processing adm_id: 3855...
# Submitting task for 1_id: 3855...
# Processing adm_id: 3856...
# Submitting task for 1_id: 3856...
# Processing adm_id: 3857...
# Submitting task for 1_id: 3857...
# Processing adm_id: 3858...
# Submitting task for 1_id: 3858...
# Processing adm_id: 3859...
# Submitting task for 1_id: 3859...
# Processing adm_id: 1767...
# Submitting task for 1_id: 1767...
# Processing adm_id: 2027...
# Submitting task for 1_id: 2027...
# ✅ All tasks submitted.

# %% [markdown]
# Combining into adm0

# %%
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
import os
import glob
import pandas as pd

# Define the folder and get all CSV file paths
hazard_folder = os.path.join('/content/drive/MyDrive', output_folder)
hazard_files = glob.glob(f'{hazard_folder}/*.csv')

# Read and concatenate all CSVs into one DataFrame
merged_df = pd.concat([pd.read_csv(f) for f in hazard_files], ignore_index=True)

# Output directory
output_dir = '/content/drive/MyDrive/p1_exposure'
os.makedirs(output_dir, exist_ok=True)

# Loop through each unique hazard and export a CSV
for hazard_name in merged_df['hazard'].unique():
    # Filter the data
    df_subset = merged_df[merged_df['hazard'] == hazard_name]

    # Define full path
    output_path = os.path.join(output_dir, f"{hazard_name}_exposure_adm0.csv")

    # Save the CSV
    df_subset.to_csv(output_path, index=False)

    print(f"✅ Saved: {output_path}")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ✅ Saved: /content/drive/MyDrive/p1_exposure/river_flood_100yr_jrc_2024_exposure_adm0.csv
# ✅ Saved: /content/drive/MyDrive/p1_exposure/coastal_flood_100yr_jrc_2024_exposure_adm0.csv
# ✅ Saved: /content/drive/MyDrive/p1_exposure/tropical_storm_100yr_giri_2024_exposure_adm0.csv
# ✅ Saved: /content/drive/MyDrive/p1_exposure/agricultural_drought_fao_1984-2023_exposure_adm0.csv
# ✅ Saved: /content/drive/MyDrive/p1_exposure/drought_spei_copernicus_1940-2024_exposure_adm0.csv
# ✅ Saved: /content/drive/MyDrive/p1_exposure/drought_spi_copernicus_1940-2024_exposure_adm0.csv
# ✅ Saved: /content/drive/MyDrive/p1_exposure/heatwave_frequency_ecmwf_2014-2024_exposure_adm0.csv
# ✅ Saved: /content/drive/MyDrive/p1_exposure/heatwave_duration_ecmwf_2014-2024_exposure_adm0.csv
# ✅ Saved: /content/drive/MyDrive/p1_exposure/heatwave_severity_ecmwf_2014-2024_exposure_adm0.csv
# ✅ Saved: /content/drive/MyDrive/p1_exposure/extreme_heat_ecmwf_2014-2024_exposure_adm0.csv
# ✅ Saved: /content/drive/MyDrive/p1_exposure/fire_FRP_nasa_2001-2024_exposure_adm0.csv
# ✅ Saved: /content/drive/MyDrive/p1_exposure/fire_frequency_nasa_2001-2023_exposure_adm0.csv
# ✅ Saved: /content/drive/MyDrive/p1_exposure/sand_dust_storm_unccd_2024_exposure_adm0.csv
# ✅ Saved: /content/drive/MyDrive/p1_exposure/air_pollution_pm25_1998-2023_exposure_adm0.csv
# ✅ Saved: /content/drive/MyDrive/p1_exposure/vectorborne_malariapv_2012-2022_exposure_adm0.csv
# ✅ Saved: /content/drive/MyDrive/p1_exposure/vectorborne_malariapf_2012-2022_exposure_adm0.csv

# %%
# Load child population and replace one image
org_childpop = ee.ImageCollection("projects/unicef-ccri/assets/childpop_constrained")
image_to_replace_id = 'tha_T_Under_18_2024_CN_100m_R2024A_v1'
new_image = ee.Image(f'projects/unicef-ccri/assets/{image_to_replace_id}').set('system:index', image_to_replace_id)
filtered_collection = org_childpop.filter(ee.Filter.neq('system:index', image_to_replace_id))
childpop = filtered_collection.merge(ee.ImageCollection([new_image])).mosaic()
scale = filtered_collection.first().projection().nominalScale()
totalpop = ee.Image("projects/unicef-ccri/assets/worldpop_1km")
totalpop_res = totalpop.projection().nominalScale()

reference_image = ee.Image("projects/unicef-ccri/assets/heatwave_frequency_2014_2023_avg")
target_scale = reference_image.projection().nominalScale()
target_crs = reference_image.projection().crs()

# Hazard list
hazards = [
    {"id": "projects/unicef-ccri/assets/river_flood_r100", "threshold": 0.01, "name": "river_flood_100yr_jrc_2024"},
    {"id": "projects/unicef-ccri/assets/coastal_flood_r100", "threshold": 0, "name": "coastal_flood_100yr_jrc_2024"},
    {"id": "projects/unicef-ccri/assets/storm_giri_rp100", "threshold": 17.5, "name": "tropical_storm_100yr_giri_2024"},
    {"id": "projects/unicef-ccri/assets/ASI_return_level_100yr", "threshold": 30, "name": "agricultural_drought_fao_1984-2023"},
    {"id": "projects/unicef-ccri/assets/drought_spei_copernicus_1940_2024", "threshold": -1.5, "name": "drought_spei_copernicus_1940-2024"},
    {"id": "projects/unicef-ccri/assets/drought_spi_copernicus_1940_2024", "threshold": -1.5, "name": "drought_spi_copernicus_1940-2024"},
    {"id": "projects/unicef-ccri/assets/heatwave_frequency_return_level_100yr", "threshold": 'Mean', "name": "heatwave_frequency_ecmwf_2014-2024"},
    {"id": "projects/unicef-ccri/assets/heatwave_duration_return_level_100yr", "threshold": 'Mean', "name": "heatwave_duration_ecmwf_2014-2024"},
    {"id": "projects/unicef-ccri/assets/heatwave_severity_return_level_100yr", "threshold": 'Mean', "name": "heatwave_severity_ecmwf_2014-2024"},
    {"id": "projects/unicef-ccri/assets/high_temp_degree_days_return_level_100yr", "threshold": 35, "name": "extreme_heat_ecmwf_2014-2024"},
    {"id": "projects/unicef-ccri/assets/FIRMS_FRP_90th_percentile", "threshold": 'Mean', "name": "fire_FRP_nasa_2001-2024"},
    {"id": "projects/unicef-ccri/assets/FIRMS_count_90th_percentile", "threshold": 'Mean', "name": "fire_frequency_nasa_2001-2023"},
    {"id": "projects/unicef-ccri/assets/sand_dust_storm_annual", "threshold": 0, "name": "sand_dust_storm_unccd_2024"},
    {"id": "projects/unicef-ccri/assets/pm25_p90_1998_2023", "threshold": 5, "name": "air_pollution_pm25_1998-2023"},
    {"id": "projects/unicef-ccri/assets/Pv_average_2013_2022", "threshold": 0.001, "name": "vectorborne_malariapv_2012-2022"},
    {"id": "projects/unicef-ccri/assets/Pf_average_2013_2022", "threshold": 0.001, "name": "vectorborne_malariapf_2012-2022"}
]

# Load country boundaries
admin_fc_path = f'projects/unicef-ccri/assets/gaul2024_{admin_level}'
country_fc = ee.FeatureCollection(admin_fc_path)
simple_fc = ee.FeatureCollection(f'projects/unicef-ccri/assets/{admin_level}_simple')
adm_ids = country_fc.aggregate_array('WFP_ID').distinct().getInfo()
global_geom = simple_fc.geometry()

# Group features by 'WFP_ID' and merge geometries
merged_fc = country_fc.distinct(['WFP_ID']).map(lambda f: f.setGeometry(
      country_fc
        .filter(ee.Filter.eq('WFP_ID', f.get('WFP_ID')))
        .geometry()
        .dissolve()
  ))



# Update thresholds if needed
for hazard in hazards:
    if hazard['threshold'] == 'Mean':
        layer = (
            ee.ImageCollection(hazard['id']).mosaic()
            if hazard['name'] in ["river_flood_100yr_jrc_2024", "coastal_flood_100yr_jrc_2024", "tropical_storm_100yr_giri_2024"]
            else ee.Image(hazard['id'])
        )
        th = layer.reduceRegion(
            reducer=ee.Reducer.mean(),
            geometry=global_geom,
            scale=target_scale,
            bestEffort=True,
            maxPixels=1e13
        ).values().get(0)
        if th is not None:
            hazard['threshold'] = ee.Number(th).getInfo()
        else:
            print(f"⚠️ Skipping hazard {hazard['name']} — global mean threshold is null.")
            hazard['skip'] = True


th_shape_area = merged_fc.filter(ee.Filter.eq('iso3_code', 'ITA')).first().getNumber('Shape_Area')

# Loop through admin regions
for adm_id in adm_ids:
    print(adm_id)
    if adm_id is None:
        continue

    # Filter feature by adm_id
    region = merged_fc.filter(ee.Filter.eq('WFP_ID', adm_id)).first()

    # Get stscod
    stscod = region.get('stscod').getInfo()

    print(f"Submitting task for {admin_level}_id: {adm_id}...")

    shape_area = region.getNumber('Shape_Area')

    # Choose simplification level based on area
    simplification_tolerance = ee.Algorithms.If(
        shape_area.gt(th_shape_area),
        10000,
        100
    )

    simplified_geom = region.geometry().simplify(simplification_tolerance)
    region_geom = ee.Geometry(simplified_geom)

    iso3_gaul = region.get('iso3_code')
    iso3_wfp = region.get('ISO3')
    wfp_id = region.get('WFP_ID')
    region_name = region.get(f'name')
    region_type = region.get(f'type')

    childpop_sum = childpop.reduceRegion(
        ee.Reducer.sum(), region_geom, scale=scale, crs='EPSG:4326', maxPixels=1e13).get('b1')
    totalpop_sum = totalpop.reduceRegion(
        ee.Reducer.sum(), region_geom, scale=totalpop_res, crs='EPSG:4326', maxPixels=1e13).get('b1')

    features = []

    for hazard in hazards:
        if hazard.get('skip'):
            continue
        name = hazard['name']
        TH = hazard['threshold']

        layer = (
            ee.ImageCollection(hazard['id']).mosaic()
            if hazard['name'] in ["river_flood_100yr_jrc_2024", "coastal_flood_100yr_jrc_2024", "tropical_storm_100yr_giri_2024"]
            else ee.Image(hazard['id'])
        )

        if name == "agricultural_drought_fao_1984-2023":
            layer = layer.updateMask(layer.lte(100))
            exposed = childpop.updateMask(layer.gt(ee.Image.constant(TH)))
        elif name in ["drought_spei_copernicus_1940-2024", "drought_spi_copernicus_1940-2024"]:
            exposed = childpop.updateMask(layer.lt(ee.Image.constant(TH)))
        else:
            exposed = childpop.updateMask(layer.gt(ee.Image.constant(TH)))


        if name == "coastal_flood_100yr_jrc_2024":
              region_geom = region_geom.buffer(5000) #buffer 5km for coastal flood
        else:
              region_geom = ee.Geometry(simplified_geom)


        exposed_sum = exposed.reduceRegion(
            ee.Reducer.sum(), region_geom, scale=scale, bestEffort=True, crs='EPSG:4326', maxPixels=1e13).get('b1')

        feature = ee.Feature(None, {

            'iso3': iso3_gaul,
            'iso3_wfp': iso3_wfp,
            'wfp_id': wfp_id,
            f'{admin_level}_name': region_name,
            'type' : region_type,
            'hazard': name,
            'child_population_exposed': exposed_sum,
            'child_population_total': childpop_sum,
            'population_total': totalpop_sum
        })
        features.append(feature)

    task = ee.batch.Export.table.toDrive(
        collection=ee.FeatureCollection(features),
        description=f"{adm_id}_hazards_{admin_level}",
        folder=output_folder,
        fileFormat='CSV',
        selectors=[
            'iso3', 'iso3_wfp', 'wfp_id', f'{admin_level}_name', 'type', 'hazard',
            'child_population_exposed', 'child_population_total', 'population_total'
        ]
    )
    task.start()


print("✅ All tasks submitted.")
