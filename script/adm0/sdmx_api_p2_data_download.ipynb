# %% [markdown]
# <a href="https://colab.research.google.com/github/dohyung-kim/ccri/blob/main/script/adm0/sdmx_api_p2_data_download.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import geopandas as gpd
import requests
import pandas as pd
import xml.etree.ElementTree as ET

# %%
outpath = input("Enter output save path:")
# /Users/kelseydoerksen/code/unicef/ccri/data/CCRI_results_misc
# Out:
# Enter output save path: /Users/kelseydoerksen/code/unicef/ccri/data/CCRI_results_misc

# %%
p2_var = input("Enter P2 save name:")
# EG: P2_basic_hygiene.csv
# P2_under5_mortality.csv
# Out:
# Enter P2 save name: P2_under5_mortality.csv

# %%
api_url_template = input("Enter api path for files to query")

# EG: this is a api url for wash basic hygiene - replace for other p2 variables
#"https://sdmx.data.unicef.org/ws/public/sdmxapi/rest/data/UNICEF,WASH_HOUSEHOLDS,1.0/{iso3}.WS_PPL_H-B.HYG._T._T?format=sdmx-compact-2.1"
# Under-5 Mortality 'https://sdmx.data.unicef.org/ws/public/sdmxapi/rest/data/UNICEF,CME,1.0/{iso3}.CME_MRY0T4..?format=sdmx-compact-2.1'
# Out:
# Enter api path for files to query https://sdmx.data.unicef.org/ws/public/sdmxapi/rest/data/UNICEF,CME,1.0/{iso3}.CME_MRY0T4..?format=sdmx-compact-2.1

# %%
# File path for the GeoJSON
geojson_file_path = input("Enter full filepath to adm0 global boundaries")
#geojson_file_path = "/content/drive/MyDrive/CCRI/global_bnd_adm0.geojson"
# Kelsey local: /Users/kelseydoerksen/code/unicef/ccri/data/misc/adm0_boundaries_simple.geojson
# Out:
# Enter full filepath to adm0 global boundaries /Users/kelseydoerksen/code/unicef/ccri/data/misc/adm0_boundaries_simple.geojson

# %%
# Function to fetch data for a single country using the UNICEF dataflow endpoint
def fetch_country_data(iso3, api_url_template):
    """
    Fetch data for a given country using its ISO3 code.
    Returns the most recent observation as a dictionary, or None if data is missing.
    """
    # Construct URL using Python's format method
    api_url = api_url_template.format(iso3=iso3)
    try:
        response = requests.get(api_url)
        if response.status_code == 200:
            try:
                # Parse XML using fromstring (handles encoding better)
                root = ET.fromstring(response.content)
            except ET.ParseError as pe:
                print(f"XML parsing error for {iso3}: {pe}")
                return None

            # The Series element is not namespaced in this response
            series = root.find(".//Series")
            if series is not None:
                obs_list = series.findall("Obs")
                if obs_list:
                    data = []
                    for obs in obs_list:
                        time_period_str = obs.get("TIME_PERIOD")
                        obs_value_str = obs.get("OBS_VALUE")
                        try:
                            time_period = int(time_period_str)
                            obs_value = float(obs_value_str)
                        except Exception as conv_err:
                            print(f"Conversion error for {iso3}: {conv_err}")
                            continue
                        data.append({
                            "iso3": iso3,
                            "time_period": time_period,
                            "obs_value": obs_value,
                            "data_source": obs.get("DATA_SOURCE")
                        })
                    if data:
                        # Choose the most recent record based on the time period
                        most_recent = max(data, key=lambda x: x["time_period"])
                        return most_recent
                    else:
                        print(f"No valid observation data for {iso3}")
                        return None
                else:
                    print(f"No observation elements found for {iso3}")
                    return None
            else:
                print(f"No Series element found for {iso3}")
                return None
        else:
            print(f"Failed to fetch data for {iso3}. HTTP Status: {response.status_code}")
            return None
    except Exception as e:
        print(f"Error processing {iso3}: {e}")
        return None

# Load the GeoJSON file containing country boundaries and ISO3 codes
countries_gdf = gpd.read_file(geojson_file_path)

# Verify the GeoDataFrame columns to ensure the ISO3 field exists
print("GeoDataFrame columns:", countries_gdf.columns)

# Extract ISO3 codes (update the field name if it's not exactly 'iso3')
iso3_codes = countries_gdf['ISO3'].unique()

# This uses {iso3} as a placeholder that will be replaced with the actual ISO3 code.
# Out:
# GeoDataFrame columns: Index(['id', 'Alternativ', 'ISO3', 'Map label', 'MapClr', 'UcodeIn', 'WFP_ID',
#        'cnpt_uuid', 'default', 'end_date', 'is_latest', 'level', 'level_name',
#        'name', 'name_en', 'start_date', 'type', 'ucode', 'uuid', 'geometry'],
#       dtype='object')

# %%
# List to store fetched data for all countries
all_data = []

# Loop through ISO3 codes, fetch data and add it to the list if available
for iso3 in iso3_codes:
    print(f"Processing {iso3}...")
    result = fetch_country_data(iso3, api_url_template)
    if result:
        print(f"Data for {iso3}: {result}")
        all_data.append(result)
    else:
        print(f"No data found for {iso3}")
# Out:
# Processing ATA...
# Failed to fetch data for ATA. HTTP Status: 404
# No data found for ATA
# Processing AIA...
# Data for AIA: {'iso3': 'AIA', 'time_period': 2023, 'obs_value': 5.8644762772405, 'data_source': None}
# Processing ESH...
# Failed to fetch data for ESH. HTTP Status: 404
# No data found for ESH
# Processing PYF...
# Failed to fetch data for PYF. HTTP Status: 404
# No data found for PYF
# Processing NCL...
# Failed to fetch data for NCL. HTTP Status: 404
# No data found for NCL
# Processing BMU...
# Failed to fetch data for BMU. HTTP Status: 404
# No data found for BMU
# Processing GIB...
# Failed to fetch data for GIB. HTTP Status: 404
# No data found for GIB
# Processing VGB...
# Data for VGB: {'iso3': 'VGB', 'time_period': 2023, 'obs_value': 12.6102522275391, 'data_source': None}
# Processing CYM...
# Failed to fetch data for CYM. HTTP Status: 404
# No data found for CYM
# Processing FLK...
# Failed to fetch data for FLK. HTTP Status: 404
# No data found for FLK
# Processing MSR...
# Data for MSR: {'iso3': 'MSR', 'time_period': 2023, 'obs_value': 6.71279946471928, 'data_source': None}
# Processing PCN...
# Failed to fetch data for PCN. HTTP Status: 404
# No data found for PCN
# Processing SHN...
# Failed to fetch data for SHN. HTTP Status: 404
# No data found for SHN
# Processing TKL...
# Failed to fetch data for TKL. HTTP Status: 404
# No data found for TKL
# Processing TCA...
# Data for TCA: {'iso3': 'TCA', 'time_period': 2023, 'obs_value': 5.02595161481019, 'data_source': None}
# Processing ASM...
# Failed to fetch data for ASM. HTTP Status: 404
# No data found for ASM
# Processing GUM...
# Failed to fetch data for GUM. HTTP Status: 404
# No data found for GUM
# Processing VIR...
# Failed to fetch data for VIR. HTTP Status: 404
# No data found for VIR
# Processing GRL...
# Failed to fetch data for GRL. HTTP Status: 404
# No data found for GRL
# Processing EGY...
# Data for EGY: {'iso3': 'EGY', 'time_period': 2023, 'obs_value': 16.316475115462, 'data_source': None}
# Processing xAP...
# Failed to fetch data for xAP. HTTP Status: 404
# No data found for xAP
# Processing xSK...
# Failed to fetch data for xSK. HTTP Status: 404
# No data found for xSK
# Processing xRI...
# Failed to fetch data for xRI. HTTP Status: 404
# No data found for xRI
# Processing SDN...
# Data for SDN: {'iso3': 'SDN', 'time_period': 2023, 'obs_value': 44.9773684399724, 'data_source': None}
# Processing SSD...
# Data for SSD: {'iso3': 'SSD', 'time_period': 2023, 'obs_value': 93.3970608864586, 'data_source': None}
# Processing xAB...
# Failed to fetch data for xAB. HTTP Status: 404
# No data found for xAB
# Processing xAC...
# Failed to fetch data for xAC. HTTP Status: 404
# No data found for xAC
# Processing xJK...
# Failed to fetch data for xJK. HTTP Status: 404
# No data found for xJK
# Processing xJL...
# Failed to fetch data for xJL. HTTP Status: 404
# No data found for xJL
# Processing xPI...
# Failed to fetch data for xPI. HTTP Status: 404
# No data found for xPI
# Processing xSI...
# Failed to fetch data for xSI. HTTP Status: 404
# No data found for xSI
# Processing xSR...
# Failed to fetch data for xSR. HTTP Status: 404
# No data found for xSR
# Processing xxx...
# Failed to fetch data for xxx. HTTP Status: 404
# No data found for xxx
# Processing MAC...
# Failed to fetch data for MAC. HTTP Status: 404
# No data found for MAC
# Processing HKG...
# Failed to fetch data for HKG. HTTP Status: 404
# No data found for HKG
# Processing TWN...
# Failed to fetch data for TWN. HTTP Status: 404
# No data found for TWN
# Processing AFG...
# Data for AFG: {'iso3': 'AFG', 'time_period': 2023, 'obs_value': 51.5784018050133, 'data_source': None}
# Processing AGO...
# Data for AGO: {'iso3': 'AGO', 'time_period': 2023, 'obs_value': 58.8069208663016, 'data_source': None}
# Processing ALB...
# Data for ALB: {'iso3': 'ALB', 'time_period': 2023, 'obs_value': 8.61259633666756, 'data_source': None}
# Processing AND...
# Data for AND: {'iso3': 'AND', 'time_period': 2023, 'obs_value': 2.24662701439679, 'data_source': None}
# Processing ARE...
# Data for ARE: {'iso3': 'ARE', 'time_period': 2023, 'obs_value': 4.54822693404086, 'data_source': None}
# Processing ARG...
# Data for ARG: {'iso3': 'ARG', 'time_period': 2023, 'obs_value': 8.76287857628204, 'data_source': None}
# Processing ARM...
# Data for ARM: {'iso3': 'ARM', 'time_period': 2023, 'obs_value': 9.04375321435773, 'data_source': None}
# Processing ATG...
# Data for ATG: {'iso3': 'ATG', 'time_period': 2023, 'obs_value': 8.4760686285009, 'data_source': None}
# Processing AUS...
# Data for AUS: {'iso3': 'AUS', 'time_period': 2023, 'obs_value': 3.35357911813504, 'data_source': None}
# Processing AUT...
# Data for AUT: {'iso3': 'AUT', 'time_period': 2023, 'obs_value': 2.84341809739518, 'data_source': None}
# Processing AZE...
# Data for AZE: {'iso3': 'AZE', 'time_period': 2023, 'obs_value': 17.3704436763207, 'data_source': None}
# Processing BDI...
# Data for BDI: {'iso3': 'BDI', 'time_period': 2023, 'obs_value': 45.0257323680534, 'data_source': None}
# Processing BEL...
# Data for BEL: {'iso3': 'BEL', 'time_period': 2023, 'obs_value': 3.2016422667531, 'data_source': None}
# Processing BEN...
# Data for BEN: {'iso3': 'BEN', 'time_period': 2023, 'obs_value': 72.4282734791332, 'data_source': None}
# Processing BFA...
# Data for BFA: {'iso3': 'BFA', 'time_period': 2023, 'obs_value': 72.6535941041748, 'data_source': None}
# Processing BGD...
# Data for BGD: {'iso3': 'BGD', 'time_period': 2023, 'obs_value': 28.3662769206882, 'data_source': None}
# Processing BGR...
# Data for BGR: {'iso3': 'BGR', 'time_period': 2023, 'obs_value': 5.57471357817788, 'data_source': None}
# Processing BHR...
# Data for BHR: {'iso3': 'BHR', 'time_period': 2023, 'obs_value': 8.3861059938364, 'data_source': None}
# Processing BHS...
# Data for BHS: {'iso3': 'BHS', 'time_period': 2023, 'obs_value': 11.6685492097889, 'data_source': None}
# Processing BIH...
# Data for BIH: {'iso3': 'BIH', 'time_period': 2023, 'obs_value': 5.5086851911653, 'data_source': None}
# Processing BLR...
# Data for BLR: {'iso3': 'BLR', 'time_period': 2023, 'obs_value': 2.14423160084508, 'data_source': None}
# Processing BLZ...
# Data for BLZ: {'iso3': 'BLZ', 'time_period': 2023, 'obs_value': 11.4454314334437, 'data_source': None}
# Processing BOL...
# Data for BOL: {'iso3': 'BOL', 'time_period': 2023, 'obs_value': 20.8158614440294, 'data_source': None}
# Processing BRA...
# Data for BRA: {'iso3': 'BRA', 'time_period': 2023, 'obs_value': 12.8180376730508, 'data_source': None}
# Processing BRB...
# Data for BRB: {'iso3': 'BRB', 'time_period': 2023, 'obs_value': 9.22484466888712, 'data_source': None}
# Processing BRN...
# Data for BRN: {'iso3': 'BRN', 'time_period': 2023, 'obs_value': 8.67092571533484, 'data_source': None}
# Processing BTN...
# Data for BTN: {'iso3': 'BTN', 'time_period': 2023, 'obs_value': 20.9138870940307, 'data_source': None}
# Processing BWA...
# Data for BWA: {'iso3': 'BWA', 'time_period': 2023, 'obs_value': 35.2507720066601, 'data_source': None}
# Processing CAF...
# Data for CAF: {'iso3': 'CAF', 'time_period': 2023, 'obs_value': 86.0024526163736, 'data_source': None}
# Processing CAN...
# Data for CAN: {'iso3': 'CAN', 'time_period': 2023, 'obs_value': 4.65926116645773, 'data_source': None}
# Processing CHE...
# Data for CHE: {'iso3': 'CHE', 'time_period': 2023, 'obs_value': 3.59421804369081, 'data_source': None}
# Processing CHL...
# Data for CHL: {'iso3': 'CHL', 'time_period': 2023, 'obs_value': 6.57591516979055, 'data_source': None}
# Processing CHN...
# Data for CHN: {'iso3': 'CHN', 'time_period': 2023, 'obs_value': 5.85689428692902, 'data_source': None}
# Processing CIV...
# Data for CIV: {'iso3': 'CIV', 'time_period': 2023, 'obs_value': 59.7436103345213, 'data_source': None}
# Processing CMR...
# Data for CMR: {'iso3': 'CMR', 'time_period': 2023, 'obs_value': 61.854780618622, 'data_source': None}
# Processing COD...
# Data for COD: {'iso3': 'COD', 'time_period': 2023, 'obs_value': 67.6241806623565, 'data_source': None}
# Processing COG...
# Data for COG: {'iso3': 'COG', 'time_period': 2023, 'obs_value': 36.7726166884536, 'data_source': None}
# Processing COL...
# Data for COL: {'iso3': 'COL', 'time_period': 2023, 'obs_value': 10.7330603406998, 'data_source': None}
# Processing COM...
# Data for COM: {'iso3': 'COM', 'time_period': 2023, 'obs_value': 37.2267206562376, 'data_source': None}
# Processing CPV...
# Data for CPV: {'iso3': 'CPV', 'time_period': 2023, 'obs_value': 10.4905731657864, 'data_source': None}
# Processing CRI...
# Data for CRI: {'iso3': 'CRI', 'time_period': 2023, 'obs_value': 9.67065538336383, 'data_source': None}
# Processing CUB...
# Data for CUB: {'iso3': 'CUB', 'time_period': 2023, 'obs_value': 7.35338823131018, 'data_source': None}
# Processing CYP...
# Data for CYP: {'iso3': 'CYP', 'time_period': 2023, 'obs_value': 3.29636975857752, 'data_source': None}
# Processing CZE...
# Data for CZE: {'iso3': 'CZE', 'time_period': 2023, 'obs_value': 2.25767992309713, 'data_source': None}
# Processing DEU...
# Data for DEU: {'iso3': 'DEU', 'time_period': 2023, 'obs_value': 3.38406413374078, 'data_source': None}
# Processing DJI...
# Data for DJI: {'iso3': 'DJI', 'time_period': 2023, 'obs_value': 45.5490138956737, 'data_source': None}
# Processing DMA...
# Data for DMA: {'iso3': 'DMA', 'time_period': 2023, 'obs_value': 33.1216645700791, 'data_source': None}
# Processing DNK...
# Data for DNK: {'iso3': 'DNK', 'time_period': 2023, 'obs_value': 3.13298164068216, 'data_source': None}
# Processing DOM...
# Data for DOM: {'iso3': 'DOM', 'time_period': 2023, 'obs_value': 28.5389703427983, 'data_source': None}
# Processing DZA...
# Data for DZA: {'iso3': 'DZA', 'time_period': 2023, 'obs_value': 20.0606950962352, 'data_source': None}
# Processing ECU...
# Data for ECU: {'iso3': 'ECU', 'time_period': 2023, 'obs_value': 11.3269024974437, 'data_source': None}
# Processing ERI...
# Data for ERI: {'iso3': 'ERI', 'time_period': 2023, 'obs_value': 31.0672060940791, 'data_source': None}
# Processing ESP...
# Data for ESP: {'iso3': 'ESP', 'time_period': 2023, 'obs_value': 2.8117261791682, 'data_source': None}
# Processing EST...
# Data for EST: {'iso3': 'EST', 'time_period': 2023, 'obs_value': 1.89080603682406, 'data_source': None}
# Processing ETH...
# Data for ETH: {'iso3': 'ETH', 'time_period': 2023, 'obs_value': 40.2908300884454, 'data_source': None}
# Processing FIN...
# Data for FIN: {'iso3': 'FIN', 'time_period': 2023, 'obs_value': 2.08968997494071, 'data_source': None}
# Processing FJI...
# Data for FJI: {'iso3': 'FJI', 'time_period': 2023, 'obs_value': 26.3575315890519, 'data_source': None}
# Processing FRA...
# Data for FRA: {'iso3': 'FRA', 'time_period': 2023, 'obs_value': 3.95457295881687, 'data_source': None}
# Processing FSM...
# Data for FSM: {'iso3': 'FSM', 'time_period': 2023, 'obs_value': 20.1078831612658, 'data_source': None}
# Processing GAB...
# Data for GAB: {'iso3': 'GAB', 'time_period': 2023, 'obs_value': 29.4193656550248, 'data_source': None}
# Processing GBR...
# Data for GBR: {'iso3': 'GBR', 'time_period': 2023, 'obs_value': 4.04193621543027, 'data_source': None}
# Processing GEO...
# Data for GEO: {'iso3': 'GEO', 'time_period': 2023, 'obs_value': 8.13498264844402, 'data_source': None}
# Processing GHA...
# Data for GHA: {'iso3': 'GHA', 'time_period': 2023, 'obs_value': 32.7875532046363, 'data_source': None}
# Processing GIN...
# Data for GIN: {'iso3': 'GIN', 'time_period': 2023, 'obs_value': 87.6846594834506, 'data_source': None}
# Processing GMB...
# Data for GMB: {'iso3': 'GMB', 'time_period': 2023, 'obs_value': 39.173697654983, 'data_source': None}
# Processing GNB...
# Data for GNB: {'iso3': 'GNB', 'time_period': 2023, 'obs_value': 63.358950355278, 'data_source': None}
# Processing GNQ...
# Data for GNQ: {'iso3': 'GNQ', 'time_period': 2023, 'obs_value': 65.0694850873233, 'data_source': None}
# Processing GRC...
# Data for GRC: {'iso3': 'GRC', 'time_period': 2023, 'obs_value': 3.43592650526383, 'data_source': None}
# Processing GRD...
# Data for GRD: {'iso3': 'GRD', 'time_period': 2023, 'obs_value': 16.6896961775834, 'data_source': None}
# Processing GTM...
# Data for GTM: {'iso3': 'GTM', 'time_period': 2023, 'obs_value': 19.0990123983625, 'data_source': None}
# Processing GUY...
# Data for GUY: {'iso3': 'GUY', 'time_period': 2023, 'obs_value': 22.4526559040786, 'data_source': None}
# Processing HND...
# Data for HND: {'iso3': 'HND', 'time_period': 2023, 'obs_value': 13.7971379971192, 'data_source': None}
# Processing HRV...
# Data for HRV: {'iso3': 'HRV', 'time_period': 2023, 'obs_value': 4.08842123116384, 'data_source': None}
# Processing HTI...
# Data for HTI: {'iso3': 'HTI', 'time_period': 2023, 'obs_value': 49.8488853751333, 'data_source': None}
# Processing HUN...
# Data for HUN: {'iso3': 'HUN', 'time_period': 2023, 'obs_value': 3.42121848884385, 'data_source': None}
# Processing IDN...
# Data for IDN: {'iso3': 'IDN', 'time_period': 2023, 'obs_value': 18.4875682513052, 'data_source': None}
# Processing IND...
# Data for IND: {'iso3': 'IND', 'time_period': 2023, 'obs_value': 27.819743935712, 'data_source': None}
# Processing IRL...
# Data for IRL: {'iso3': 'IRL', 'time_period': 2023, 'obs_value': 3.51334848707148, 'data_source': None}
# Processing IRN...
# Data for IRN: {'iso3': 'IRN', 'time_period': 2023, 'obs_value': 11.1536074345561, 'data_source': None}
# Processing IRQ...
# Data for IRQ: {'iso3': 'IRQ', 'time_period': 2023, 'obs_value': 20.3552521140047, 'data_source': None}
# Processing ISL...
# Data for ISL: {'iso3': 'ISL', 'time_period': 2023, 'obs_value': 2.3778590533754, 'data_source': None}
# Processing ISR...
# Data for ISR: {'iso3': 'ISR', 'time_period': 2023, 'obs_value': 3.11241677414455, 'data_source': None}
# Processing ITA...
# Data for ITA: {'iso3': 'ITA', 'time_period': 2023, 'obs_value': 2.52748254430606, 'data_source': None}
# Processing JAM...
# Data for JAM: {'iso3': 'JAM', 'time_period': 2023, 'obs_value': 16.8460908322717, 'data_source': None}
# Processing JOR...
# Data for JOR: {'iso3': 'JOR', 'time_period': 2023, 'obs_value': 11.9273807158689, 'data_source': None}
# Processing JPN...
# Data for JPN: {'iso3': 'JPN', 'time_period': 2023, 'obs_value': 2.24687068253348, 'data_source': None}
# Processing KAZ...
# Data for KAZ: {'iso3': 'KAZ', 'time_period': 2023, 'obs_value': 8.43472105117776, 'data_source': None}
# Processing KEN...
# Data for KEN: {'iso3': 'KEN', 'time_period': 2023, 'obs_value': 35.6014681970815, 'data_source': None}
# Processing KGZ...
# Data for KGZ: {'iso3': 'KGZ', 'time_period': 2023, 'obs_value': 14.9481608643508, 'data_source': None}
# Processing KHM...
# Data for KHM: {'iso3': 'KHM', 'time_period': 2023, 'obs_value': 20.2320257276906, 'data_source': None}
# Processing KIR...
# Data for KIR: {'iso3': 'KIR', 'time_period': 2023, 'obs_value': 50.4543873187635, 'data_source': None}
# Processing KNA...
# Data for KNA: {'iso3': 'KNA', 'time_period': 2023, 'obs_value': 14.5693288514993, 'data_source': None}
# Processing KOR...
# Data for KOR: {'iso3': 'KOR', 'time_period': 2023, 'obs_value': 2.49730161964887, 'data_source': None}
# Processing KWT...
# Data for KWT: {'iso3': 'KWT', 'time_period': 2023, 'obs_value': 7.91177772027963, 'data_source': None}
# Processing LAO...
# Data for LAO: {'iso3': 'LAO', 'time_period': 2023, 'obs_value': 34.4975247853632, 'data_source': None}
# Processing LBN...
# Data for LBN: {'iso3': 'LBN', 'time_period': 2023, 'obs_value': 16.9697464383592, 'data_source': None}
# Processing LBR...
# Data for LBR: {'iso3': 'LBR', 'time_period': 2023, 'obs_value': 66.2858552862991, 'data_source': None}
# Processing LBY...
# Data for LBY: {'iso3': 'LBY', 'time_period': 2023, 'obs_value': 29.807387148599, 'data_source': None}
# Processing LCA...
# Data for LCA: {'iso3': 'LCA', 'time_period': 2023, 'obs_value': 14.1050270401257, 'data_source': None}
# Processing LIE...
# Failed to fetch data for LIE. HTTP Status: 404
# No data found for LIE
# Processing LKA...
# Data for LKA: {'iso3': 'LKA', 'time_period': 2023, 'obs_value': 5.46466242948503, 'data_source': None}
# Processing LSO...
# Data for LSO: {'iso3': 'LSO', 'time_period': 2023, 'obs_value': 52.8302766496643, 'data_source': None}
# Processing LTU...
# Data for LTU: {'iso3': 'LTU', 'time_period': 2023, 'obs_value': 3.07352040927394, 'data_source': None}
# Processing LUX...
# Data for LUX: {'iso3': 'LUX', 'time_period': 2023, 'obs_value': 2.11393269393192, 'data_source': None}
# Processing LVA...
# Data for LVA: {'iso3': 'LVA', 'time_period': 2023, 'obs_value': 2.72432094713049, 'data_source': None}
# Processing MAR...
# Data for MAR: {'iso3': 'MAR', 'time_period': 2023, 'obs_value': 14.8985834272154, 'data_source': None}
# Processing MCO...
# Data for MCO: {'iso3': 'MCO', 'time_period': 2023, 'obs_value': 2.4577916759715, 'data_source': None}
# Processing MDA...
# Data for MDA: {'iso3': 'MDA', 'time_period': 2023, 'obs_value': 12.9891380470545, 'data_source': None}
# Processing MDG...
# Data for MDG: {'iso3': 'MDG', 'time_period': 2023, 'obs_value': 59.4596435182509, 'data_source': None}
# Processing MDV...
# Data for MDV: {'iso3': 'MDV', 'time_period': 2023, 'obs_value': 5.23435140634376, 'data_source': None}
# Processing MEX...
# Data for MEX: {'iso3': 'MEX', 'time_period': 2023, 'obs_value': 11.2325777019628, 'data_source': None}
# Processing MHL...
# Data for MHL: {'iso3': 'MHL', 'time_period': 2023, 'obs_value': 24.8349838471691, 'data_source': None}
# Processing MKD...
# Data for MKD: {'iso3': 'MKD', 'time_period': 2023, 'obs_value': 3.07215980823436, 'data_source': None}
# Processing MLI...
# Data for MLI: {'iso3': 'MLI', 'time_period': 2023, 'obs_value': 86.0987297347508, 'data_source': None}
# Processing MLT...
# Data for MLT: {'iso3': 'MLT', 'time_period': 2023, 'obs_value': 5.1021169179766, 'data_source': None}
# Processing MMR...
# Data for MMR: {'iso3': 'MMR', 'time_period': 2023, 'obs_value': 34.5695083540838, 'data_source': None}
# Processing MNE...
# Data for MNE: {'iso3': 'MNE', 'time_period': 2023, 'obs_value': 2.41741697984116, 'data_source': None}
# Processing MNG...
# Data for MNG: {'iso3': 'MNG', 'time_period': 2023, 'obs_value': 12.1708769790297, 'data_source': None}
# Processing MOZ...
# Data for MOZ: {'iso3': 'MOZ', 'time_period': 2023, 'obs_value': 57.1249907070399, 'data_source': None}
# Processing MRT...
# Data for MRT: {'iso3': 'MRT', 'time_period': 2023, 'obs_value': 33.8836088924229, 'data_source': None}
# Processing MUS...
# Data for MUS: {'iso3': 'MUS', 'time_period': 2023, 'obs_value': 13.5032794293533, 'data_source': None}
# Processing MWI...
# Data for MWI: {'iso3': 'MWI', 'time_period': 2023, 'obs_value': 33.9751945910304, 'data_source': None}
# Processing MYS...
# Data for MYS: {'iso3': 'MYS', 'time_period': 2023, 'obs_value': 7.32018157309536, 'data_source': None}
# Processing NAM...
# Data for NAM: {'iso3': 'NAM', 'time_period': 2023, 'obs_value': 36.5595598890676, 'data_source': None}
# Processing NER...
# Data for NER: {'iso3': 'NER', 'time_period': 2023, 'obs_value': 110.71760304876, 'data_source': None}
# Processing NGA...
# Data for NGA: {'iso3': 'NGA', 'time_period': 2023, 'obs_value': 99.4589984642371, 'data_source': None}
# Processing NIC...
# Data for NIC: {'iso3': 'NIC', 'time_period': 2023, 'obs_value': 11.9622895104784, 'data_source': None}
# Processing NLD...
# Data for NLD: {'iso3': 'NLD', 'time_period': 2023, 'obs_value': 3.55782918443874, 'data_source': None}
# Processing NOR...
# Data for NOR: {'iso3': 'NOR', 'time_period': 2023, 'obs_value': 2.11504743492785, 'data_source': None}
# Processing NPL...
# Data for NPL: {'iso3': 'NPL', 'time_period': 2023, 'obs_value': 24.3538360074726, 'data_source': None}
# Processing NRU...
# Data for NRU: {'iso3': 'NRU', 'time_period': 2023, 'obs_value': 8.06395151175434, 'data_source': None}
# Processing NZL...
# Data for NZL: {'iso3': 'NZL', 'time_period': 2023, 'obs_value': 4.30010157549072, 'data_source': None}
# Processing OMN...
# Data for OMN: {'iso3': 'OMN', 'time_period': 2023, 'obs_value': 9.45807308778585, 'data_source': None}
# Processing PAK...
# Data for PAK: {'iso3': 'PAK', 'time_period': 2023, 'obs_value': 53.80278348712, 'data_source': None}
# Processing PAN...
# Data for PAN: {'iso3': 'PAN', 'time_period': 2023, 'obs_value': 12.1461991185987, 'data_source': None}
# Processing PER...
# Data for PER: {'iso3': 'PER', 'time_period': 2023, 'obs_value': 14.1902482269921, 'data_source': None}
# Processing PHL...
# Data for PHL: {'iso3': 'PHL', 'time_period': 2023, 'obs_value': 23.9999822653496, 'data_source': None}
# Processing PLW...
# Data for PLW: {'iso3': 'PLW', 'time_period': 2023, 'obs_value': 19.949093961448, 'data_source': None}
# Processing PNG...
# Data for PNG: {'iso3': 'PNG', 'time_period': 2023, 'obs_value': 36.9742642027022, 'data_source': None}
# Processing POL...
# Data for POL: {'iso3': 'POL', 'time_period': 2023, 'obs_value': 3.90648363389568, 'data_source': None}
# Processing PRK...
# Data for PRK: {'iso3': 'PRK', 'time_period': 2023, 'obs_value': 16.0500055261162, 'data_source': None}
# Processing PRT...
# Data for PRT: {'iso3': 'PRT', 'time_period': 2023, 'obs_value': 2.85837115382828, 'data_source': None}
# Processing PRY...
# Data for PRY: {'iso3': 'PRY', 'time_period': 2023, 'obs_value': 15.3040644958607, 'data_source': None}
# Processing PSE...
# Data for PSE: {'iso3': 'PSE', 'time_period': 2023, 'obs_value': 25.0791721144133, 'data_source': None}
# Processing QAT...
# Data for QAT: {'iso3': 'QAT', 'time_period': 2023, 'obs_value': 5.64421538222263, 'data_source': None}
# Processing ROU...
# Data for ROU: {'iso3': 'ROU', 'time_period': 2023, 'obs_value': 6.04295184266934, 'data_source': None}
# Processing RUS...
# Data for RUS: {'iso3': 'RUS', 'time_period': 2023, 'obs_value': 4.02729946713853, 'data_source': None}
# Processing RWA...
# Data for RWA: {'iso3': 'RWA', 'time_period': 2023, 'obs_value': 36.115174056436, 'data_source': None}
# Processing SAU...
# Data for SAU: {'iso3': 'SAU', 'time_period': 2023, 'obs_value': 6.03016602664029, 'data_source': None}
# Processing SEN...
# Data for SEN: {'iso3': 'SEN', 'time_period': 2023, 'obs_value': 34.112584841381, 'data_source': None}
# Processing SGP...
# Data for SGP: {'iso3': 'SGP', 'time_period': 2023, 'obs_value': 1.90647035099297, 'data_source': None}
# Processing SLB...
# Data for SLB: {'iso3': 'SLB', 'time_period': 2023, 'obs_value': 18.7823390619712, 'data_source': None}
# Processing SLE...
# Data for SLE: {'iso3': 'SLE', 'time_period': 2023, 'obs_value': 88.3672985077287, 'data_source': None}
# Processing SLV...
# Data for SLV: {'iso3': 'SLV', 'time_period': 2023, 'obs_value': 9.42714424482414, 'data_source': None}
# Processing SMR...
# Data for SMR: {'iso3': 'SMR', 'time_period': 2023, 'obs_value': 1.30742041721599, 'data_source': None}
# Processing SOM...
# Data for SOM: {'iso3': 'SOM', 'time_period': 2023, 'obs_value': 98.0915141402957, 'data_source': None}
# Processing SRB...
# Data for SRB: {'iso3': 'SRB', 'time_period': 2023, 'obs_value': 4.67616335909627, 'data_source': None}
# Processing STP...
# Data for STP: {'iso3': 'STP', 'time_period': 2023, 'obs_value': 12.5061347235444, 'data_source': None}
# Processing SUR...
# Data for SUR: {'iso3': 'SUR', 'time_period': 2023, 'obs_value': 14.249286841612, 'data_source': None}
# Processing SVK...
# Data for SVK: {'iso3': 'SVK', 'time_period': 2023, 'obs_value': 5.43614915384177, 'data_source': None}
# Processing SVN...
# Data for SVN: {'iso3': 'SVN', 'time_period': 2023, 'obs_value': 2.04923575773581, 'data_source': None}
# Processing SWE...
# Data for SWE: {'iso3': 'SWE', 'time_period': 2023, 'obs_value': 2.24806796383203, 'data_source': None}
# Processing SWZ...
# Data for SWZ: {'iso3': 'SWZ', 'time_period': 2023, 'obs_value': 40.1980852047423, 'data_source': None}
# Processing SYC...
# Data for SYC: {'iso3': 'SYC', 'time_period': 2023, 'obs_value': 13.1236655906375, 'data_source': None}
# Processing SYR...
# Data for SYR: {'iso3': 'SYR', 'time_period': 2023, 'obs_value': 18.474612537691, 'data_source': None}
# Processing TCD...
# Data for TCD: {'iso3': 'TCD', 'time_period': 2023, 'obs_value': 94.8494804809806, 'data_source': None}
# Processing TGO...
# Data for TGO: {'iso3': 'TGO', 'time_period': 2023, 'obs_value': 53.7198221758422, 'data_source': None}
# Processing THA...
# Data for THA: {'iso3': 'THA', 'time_period': 2023, 'obs_value': 8.27325282585275, 'data_source': None}
# Processing TJK...
# Data for TJK: {'iso3': 'TJK', 'time_period': 2023, 'obs_value': 23.8818787336357, 'data_source': None}
# Processing TKM...
# Data for TKM: {'iso3': 'TKM', 'time_period': 2023, 'obs_value': 34.6772447748577, 'data_source': None}
# Processing TLS...
# Data for TLS: {'iso3': 'TLS', 'time_period': 2023, 'obs_value': 45.7835109564516, 'data_source': None}
# Processing TON...
# Data for TON: {'iso3': 'TON', 'time_period': 2023, 'obs_value': 8.83680426820017, 'data_source': None}
# Processing TTO...
# Data for TTO: {'iso3': 'TTO', 'time_period': 2023, 'obs_value': 17.2603059936196, 'data_source': None}
# Processing TUN...
# Data for TUN: {'iso3': 'TUN', 'time_period': 2023, 'obs_value': 12.0772124792714, 'data_source': None}
# Processing TUR...
# Data for TUR: {'iso3': 'TUR', 'time_period': 2023, 'obs_value': 12.0930603908344, 'data_source': None}
# Processing TUV...
# Data for TUV: {'iso3': 'TUV', 'time_period': 2023, 'obs_value': 17.570298114405, 'data_source': None}
# Processing TZA...
# Data for TZA: {'iso3': 'TZA', 'time_period': 2023, 'obs_value': 34.9854154150099, 'data_source': None}
# Processing UGA...
# Data for UGA: {'iso3': 'UGA', 'time_period': 2023, 'obs_value': 34.6093848710973, 'data_source': None}
# Processing UKR...
# Data for UKR: {'iso3': 'UKR', 'time_period': 2023, 'obs_value': 7.24771675201641, 'data_source': None}
# Processing URY...
# Data for URY: {'iso3': 'URY', 'time_period': 2023, 'obs_value': 5.92128926534747, 'data_source': None}
# Processing USA...
# Data for USA: {'iso3': 'USA', 'time_period': 2023, 'obs_value': 5.91223800904557, 'data_source': None}
# Processing UZB...
# Data for UZB: {'iso3': 'UZB', 'time_period': 2023, 'obs_value': 11.6029441098891, 'data_source': None}
# Processing VAT...
# Failed to fetch data for VAT. HTTP Status: 404
# No data found for VAT
# Processing VCT...
# Data for VCT: {'iso3': 'VCT', 'time_period': 2023, 'obs_value': 9.66172432147595, 'data_source': None}
# Processing VEN...
# Data for VEN: {'iso3': 'VEN', 'time_period': 2023, 'obs_value': 22.1956208868541, 'data_source': None}
# Processing VNM...
# Data for VNM: {'iso3': 'VNM', 'time_period': 2023, 'obs_value': 16.3376125395879, 'data_source': None}
# Processing VUT...
# Data for VUT: {'iso3': 'VUT', 'time_period': 2023, 'obs_value': 15.6094269454747, 'data_source': None}
# Processing WSM...
# Data for WSM: {'iso3': 'WSM', 'time_period': 2023, 'obs_value': 14.0960733962078, 'data_source': None}
# Processing YEM...
# Data for YEM: {'iso3': 'YEM', 'time_period': 2023, 'obs_value': 35.5278428991415, 'data_source': None}
# Processing ZAF...
# Data for ZAF: {'iso3': 'ZAF', 'time_period': 2023, 'obs_value': 31.9171319663629, 'data_source': None}
# Processing ZMB...
# Data for ZMB: {'iso3': 'ZMB', 'time_period': 2023, 'obs_value': 40.52257184158, 'data_source': None}
# Processing ZWE...
# Data for ZWE: {'iso3': 'ZWE', 'time_period': 2023, 'obs_value': 39.341439545067, 'data_source': None}
# Processing CXR...
# Failed to fetch data for CXR. HTTP Status: 404
# No data found for CXR
# Processing CCK...
# Failed to fetch data for CCK. HTTP Status: 404
# No data found for CCK
# Processing HMD...
# Failed to fetch data for HMD. HTTP Status: 404
# No data found for HMD
# Processing NFK...
# Failed to fetch data for NFK. HTTP Status: 404
# No data found for NFK
# Processing FRO...
# Failed to fetch data for FRO. HTTP Status: 404
# No data found for FRO
# Processing ALA...
# Failed to fetch data for ALA. HTTP Status: 404
# No data found for ALA
# Processing ATF...
# Failed to fetch data for ATF. HTTP Status: 404
# No data found for ATF
# Processing GUF...
# Failed to fetch data for GUF. HTTP Status: 404
# No data found for GUF
# Processing GLP...
# Failed to fetch data for GLP. HTTP Status: 404
# No data found for GLP
# Processing MTQ...
# Failed to fetch data for MTQ. HTTP Status: 404
# No data found for MTQ
# Processing BLM...
# Failed to fetch data for BLM. HTTP Status: 404
# No data found for BLM
# Processing MYT...
# Failed to fetch data for MYT. HTTP Status: 404
# No data found for MYT
# Processing REU...
# Failed to fetch data for REU. HTTP Status: 404
# No data found for REU
# Processing SPM...
# Failed to fetch data for SPM. HTTP Status: 404
# No data found for SPM
# Processing xFR...
# Failed to fetch data for xFR. HTTP Status: 404
# No data found for xFR
# Processing WLF...
# Failed to fetch data for WLF. HTTP Status: 404
# No data found for WLF
# Processing MAF...
# Failed to fetch data for MAF. HTTP Status: 404
# No data found for MAF
# Processing IOT...
# Failed to fetch data for IOT. HTTP Status: 404
# No data found for IOT
# Processing GGY...
# Failed to fetch data for GGY. HTTP Status: 404
# No data found for GGY
# Processing IMN...
# Failed to fetch data for IMN. HTTP Status: 404
# No data found for IMN
# Processing JEY...
# Failed to fetch data for JEY. HTTP Status: 404
# No data found for JEY
# Processing SGS...
# Failed to fetch data for SGS. HTTP Status: 404
# No data found for SGS
# Processing xUK...
# Failed to fetch data for xUK. HTTP Status: 404
# No data found for xUK
# Processing ABW...
# Failed to fetch data for ABW. HTTP Status: 404
# No data found for ABW
# Processing CUW...
# Failed to fetch data for CUW. HTTP Status: 404
# No data found for CUW
# Processing BES...
# Failed to fetch data for BES. HTTP Status: 404
# No data found for BES
# Processing SXM...
# Failed to fetch data for SXM. HTTP Status: 404
# No data found for SXM
# Processing BVT...
# Failed to fetch data for BVT. HTTP Status: 404
# No data found for BVT
# Processing SJM...
# Failed to fetch data for SJM. HTTP Status: 404
# No data found for SJM
# Processing COK...
# Data for COK: {'iso3': 'COK', 'time_period': 2023, 'obs_value': 12.9509261965716, 'data_source': None}
# Processing NIU...
# Data for NIU: {'iso3': 'NIU', 'time_period': 2023, 'obs_value': 21.6033212359545, 'data_source': None}
# Processing UMI...
# Failed to fetch data for UMI. HTTP Status: 404
# No data found for UMI
# Processing MNP...
# Failed to fetch data for MNP. HTTP Status: 404
# No data found for MNP
# Processing PRI...
# Failed to fetch data for PRI. HTTP Status: 404
# No data found for PRI

# %%
# If any data was collected, convert it to a DataFrame and export to CSV
if all_data:
    df = pd.DataFrame(all_data)
    csv_file_path = os.path.join(outpath,"{}".format(p2_var))
    df.to_csv(csv_file_path, index=False)
    print(f"Data successfully exported to {csv_file_path}")
else:
    print("No data was fetched to export.")
# Out:
# Data successfully exported to /Users/kelseydoerksen/code/unicef/ccri/data/CCRI_results_misc/P2_under5_mortality.csv
