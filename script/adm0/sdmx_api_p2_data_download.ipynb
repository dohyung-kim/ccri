# %% [markdown]
# <a href="https://colab.research.google.com/github/dohyung-kim/ccri/blob/main/script/adm0/sdmx_api_p2_data_download.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import geopandas as gpd
import requests
import pandas as pd
import xml.etree.ElementTree as ET

outpath = "/content/drive/p2_vulnerability/"

# Function to fetch data for a single country using the UNICEF dataflow endpoint
def fetch_country_data(iso3, api_url_template):
    """
    Fetch data for a given country using its ISO3 code.
    Returns the most recent observation as a dictionary, or None if data is missing.
    """
    # Construct URL using Python's format method
    api_url = api_url_template.format(iso3=iso3)
    try:
        response = requests.get(api_url)
        if response.status_code == 200:
            try:
                # Parse XML using fromstring (handles encoding better)
                root = ET.fromstring(response.content)
            except ET.ParseError as pe:
                print(f"XML parsing error for {iso3}: {pe}")
                return None

            # The Series element is not namespaced in this response
            series = root.find(".//Series")
            if series is not None:
                obs_list = series.findall("Obs")
                if obs_list:
                    data = []
                    for obs in obs_list:
                        time_period_str = obs.get("TIME_PERIOD")
                        obs_value_str = obs.get("OBS_VALUE")
                        try:
                            time_period = int(time_period_str)
                            obs_value = float(obs_value_str)
                        except Exception as conv_err:
                            print(f"Conversion error for {iso3}: {conv_err}")
                            continue
                        data.append({
                            "iso3": iso3,
                            "time_period": time_period,
                            "obs_value": obs_value,
                            "data_source": obs.get("DATA_SOURCE")
                        })
                    if data:
                        # Choose the most recent record based on the time period
                        most_recent = max(data, key=lambda x: x["time_period"])
                        return most_recent
                    else:
                        print(f"No valid observation data for {iso3}")
                        return None
                else:
                    print(f"No observation elements found for {iso3}")
                    return None
            else:
                print(f"No Series element found for {iso3}")
                return None
        else:
            print(f"Failed to fetch data for {iso3}. HTTP Status: {response.status_code}")
            return None
    except Exception as e:
        print(f"Error processing {iso3}: {e}")
        return None

# File path for the GeoJSON (update this path as needed)
geojson_file_path = "/content/drive/MyDrive/CCRI/global_bnd_adm0.geojson"

# Load the GeoJSON file containing country boundaries and ISO3 codes
countries_gdf = gpd.read_file(geojson_file_path)

# Verify the GeoDataFrame columns to ensure the ISO3 field exists
print("GeoDataFrame columns:", countries_gdf.columns)

# Extract ISO3 codes (update the field name if it's not exactly 'iso3')
iso3_codes = countries_gdf['iso3'].unique()

# This uses {iso3} as a placeholder that will be replaced with the actual ISO3 code.
api_url_template = (
    #this is a api url for wash basic hygiene - replace for other p2 variables
    "https://sdmx.data.unicef.org/ws/public/sdmxapi/rest/data/UNICEF,WASH_HOUSEHOLDS,1.0/{iso3}.WS_PPL_H-B.HYG._T._T?format=sdmx-compact-2.1"
)

# List to store fetched data for all countries
all_data = []

# Loop through ISO3 codes, fetch data and add it to the list if available
for iso3 in iso3_codes:
    print(f"Processing {iso3}...")
    result = fetch_country_data(iso3, api_url_template)
    if result:
        print(f"Data for {iso3}: {result}")
        all_data.append(result)
    else:
        print(f"No data found for {iso3}")

# If any data was collected, convert it to a DataFrame and export to CSV
if all_data:
    df = pd.DataFrame(all_data)
    csv_file_path = os.path.join(outpath,"P2_basic_hygiene.csv")
    df.to_csv(csv_file_path, index=False)
    print(f"Data successfully exported to {csv_file_path}")
else:
    print("No data was fetched to export.")
# Out:
# GeoDataFrame columns: Index(['OBJECTID', 'iso3', 'adm0_name', 'map_lab', 'adm0_altnm', 'adm0_id',
#        'mapclr', 'rb', 'disp_area', 'stscod', 'source', 'source_date',
#        'lst_update', 'validity', 'Shape_Length', 'Shape_Area', 'geometry'],
#       dtype='object')
# Processing AFG...
# Data for AFG: {'iso3': 'AFG', 'time_period': 2022, 'obs_value': 48.21469648071023, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing xAC...
# Failed to fetch data for xAC. HTTP Status: 404
# No data found for xAC
# Processing ALB...
# Failed to fetch data for ALB. HTTP Status: 404
# No data found for ALB
# Processing DZA...
# Data for DZA: {'iso3': 'DZA', 'time_period': 2022, 'obs_value': 84.80409719593644, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing ASM...
# Failed to fetch data for ASM. HTTP Status: 404
# No data found for ASM
# Processing AND...
# Failed to fetch data for AND. HTTP Status: 404
# No data found for AND
# Processing AGO...
# Data for AGO: {'iso3': 'AGO', 'time_period': 2020, 'obs_value': 27.09419391608164, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing ARG...
# Failed to fetch data for ARG. HTTP Status: 404
# No data found for ARG
# Processing ARM...
# Data for ARM: {'iso3': 'ARM', 'time_period': 2022, 'obs_value': 94.42366241906136, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing ABW...
# Data for ABW: {'iso3': 'ABW', 'time_period': 2022, 'obs_value': 99.3, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing xAP...
# Failed to fetch data for xAP. HTTP Status: 404
# No data found for xAP
# Processing TCA...
# Data for TCA: {'iso3': 'TCA', 'time_period': 2022, 'obs_value': 94.97670485215562, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing AIA...
# Failed to fetch data for AIA. HTTP Status: 404
# No data found for AIA
# Processing ATA...
# Failed to fetch data for ATA. HTTP Status: 404
# No data found for ATA
# Processing ATG...
# Failed to fetch data for ATG. HTTP Status: 404
# No data found for ATG
# Processing AUS...
# Failed to fetch data for AUS. HTTP Status: 404
# No data found for AUS
# Processing AUT...
# Failed to fetch data for AUT. HTTP Status: 404
# No data found for AUT
# Processing AZE...
# Data for AZE: {'iso3': 'AZE', 'time_period': 2017, 'obs_value': 89.30402118333478, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing BHS...
# Failed to fetch data for BHS. HTTP Status: 404
# No data found for BHS
# Processing BHR...
# Data for BHR: {'iso3': 'BHR', 'time_period': 2022, 'obs_value': 100.0, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing UMI...
# Failed to fetch data for UMI. HTTP Status: 404
# No data found for UMI
# Processing BGD...
# Data for BGD: {'iso3': 'BGD', 'time_period': 2022, 'obs_value': 65.73719948622048, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing BRB...
# Data for BRB: {'iso3': 'BRB', 'time_period': 2016, 'obs_value': 88.46935060836856, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing FRA...
# Failed to fetch data for FRA. HTTP Status: 404
# No data found for FRA
# Processing ATF...
# Failed to fetch data for ATF. HTTP Status: 404
# No data found for ATF
# Processing BLR...
# Failed to fetch data for BLR. HTTP Status: 404
# No data found for BLR
# Processing BEL...
# Failed to fetch data for BEL. HTTP Status: 404
# No data found for BEL
# Processing BLZ...
# Data for BLZ: {'iso3': 'BLZ', 'time_period': 2022, 'obs_value': 90.28829048819193, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing BMU...
# Failed to fetch data for BMU. HTTP Status: 404
# No data found for BMU
# Processing BTN...
# Data for BTN: {'iso3': 'BTN', 'time_period': 2022, 'obs_value': 93.20417815824595, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing VEN...
# Failed to fetch data for VEN. HTTP Status: 404
# No data found for VEN
# Processing BOL...
# Data for BOL: {'iso3': 'BOL', 'time_period': 2022, 'obs_value': 26.98736682797088, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing BIH...
# Data for BIH: {'iso3': 'BIH', 'time_period': 2016, 'obs_value': 97.2610580225998, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing BWA...
# Failed to fetch data for BWA. HTTP Status: 404
# No data found for BWA
# Processing BVT...
# Failed to fetch data for BVT. HTTP Status: 404
# No data found for BVT
# Processing BRA...
# Failed to fetch data for BRA. HTTP Status: 404
# No data found for BRA
# Processing GUF...
# Failed to fetch data for GUF. HTTP Status: 404
# No data found for GUF
# Processing PYF...
# Failed to fetch data for PYF. HTTP Status: 404
# No data found for PYF
# Processing GAB...
# Failed to fetch data for GAB. HTTP Status: 404
# No data found for GAB
# Processing GMB...
# Data for GMB: {'iso3': 'GMB', 'time_period': 2022, 'obs_value': 12.94233417005425, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing GEO...
# Data for GEO: {'iso3': 'GEO', 'time_period': 2022, 'obs_value': 91.75734932832862, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing DEU...
# Failed to fetch data for DEU. HTTP Status: 404
# No data found for DEU
# Processing GHA...
# Data for GHA: {'iso3': 'GHA', 'time_period': 2022, 'obs_value': 41.68938799276566, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing GIB...
# Failed to fetch data for GIB. HTTP Status: 404
# No data found for GIB
# Processing IOT...
# Failed to fetch data for IOT. HTTP Status: 404
# No data found for IOT
# Processing VGB...
# Failed to fetch data for VGB. HTTP Status: 404
# No data found for VGB
# Processing BRN...
# Failed to fetch data for BRN. HTTP Status: 404
# No data found for BRN
# Processing BGR...
# Failed to fetch data for BGR. HTTP Status: 404
# No data found for BGR
# Processing BFA...
# Data for BFA: {'iso3': 'BFA', 'time_period': 2022, 'obs_value': 9.15637010428493, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing BDI...
# Data for BDI: {'iso3': 'BDI', 'time_period': 2022, 'obs_value': 6.303589722301413, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing KHM...
# Data for KHM: {'iso3': 'KHM', 'time_period': 2022, 'obs_value': 83.3505318947043, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing CAN...
# Failed to fetch data for CAN. HTTP Status: 404
# No data found for CAN
# Processing CPV...
# Failed to fetch data for CPV. HTTP Status: 404
# No data found for CPV
# Processing CYM...
# Failed to fetch data for CYM. HTTP Status: 404
# No data found for CYM
# Processing CHL...
# Failed to fetch data for CHL. HTTP Status: 404
# No data found for CHL
# Processing xxx...
# Failed to fetch data for xxx. HTTP Status: 404
# No data found for xxx
# Processing CHN...
# Data for CHN: {'iso3': 'CHN', 'time_period': 2022, 'obs_value': 97.20679699546234, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing CXR...
# Failed to fetch data for CXR. HTTP Status: 404
# No data found for CXR
# Processing GRC...
# Failed to fetch data for GRC. HTTP Status: 404
# No data found for GRC
# Processing GRL...
# Failed to fetch data for GRL. HTTP Status: 404
# No data found for GRL
# Processing GRD...
# Failed to fetch data for GRD. HTTP Status: 404
# No data found for GRD
# Processing CCK...
# Failed to fetch data for CCK. HTTP Status: 404
# No data found for CCK
# Processing COK...
# Failed to fetch data for COK. HTTP Status: 404
# No data found for COK
# Processing CRI...
# Data for CRI: {'iso3': 'CRI', 'time_period': 2022, 'obs_value': 85.95693421576698, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing HRV...
# Failed to fetch data for HRV. HTTP Status: 404
# No data found for HRV
# Processing CYP...
# Failed to fetch data for CYP. HTTP Status: 404
# No data found for CYP
# Processing CZE...
# Failed to fetch data for CZE. HTTP Status: 404
# No data found for CZE
# Processing CIV...
# Data for CIV: {'iso3': 'CIV', 'time_period': 2022, 'obs_value': 21.81495911756446, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing PRK...
# Failed to fetch data for PRK. HTTP Status: 404
# No data found for PRK
# Processing DNK...
# Failed to fetch data for DNK. HTTP Status: 404
# No data found for DNK
# Processing DJI...
# Failed to fetch data for DJI. HTTP Status: 404
# No data found for DJI
# Processing DOM...
# Data for DOM: {'iso3': 'DOM', 'time_period': 2022, 'obs_value': 48.32485427829707, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing ECU...
# Data for ECU: {'iso3': 'ECU', 'time_period': 2022, 'obs_value': 87.22955290055876, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing SLV...
# Data for SLV: {'iso3': 'SLV', 'time_period': 2018, 'obs_value': 90.69957921066158, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing GNQ...
# Data for GNQ: {'iso3': 'GNQ', 'time_period': 2015, 'obs_value': 24.22103751672799, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing ERI...
# Failed to fetch data for ERI. HTTP Status: 404
# No data found for ERI
# Processing EST...
# Failed to fetch data for EST. HTTP Status: 404
# No data found for EST
# Processing ETH...
# Data for ETH: {'iso3': 'ETH', 'time_period': 2022, 'obs_value': 8.321746212478427, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing FLK...
# Failed to fetch data for FLK. HTTP Status: 404
# No data found for FLK
# Processing FRO...
# Failed to fetch data for FRO. HTTP Status: 404
# No data found for FRO
# Processing FIN...
# Failed to fetch data for FIN. HTTP Status: 404
# No data found for FIN
# Processing GLP...
# Failed to fetch data for GLP. HTTP Status: 404
# No data found for GLP
# Processing GUM...
# Failed to fetch data for GUM. HTTP Status: 404
# No data found for GUM
# Processing xAB...
# Failed to fetch data for xAB. HTTP Status: 404
# No data found for xAB
# Processing GTM...
# Data for GTM: {'iso3': 'GTM', 'time_period': 2019, 'obs_value': 76.76641767207015, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing GGY...
# Failed to fetch data for GGY. HTTP Status: 404
# No data found for GGY
# Processing GNB...
# Data for GNB: {'iso3': 'GNB', 'time_period': 2022, 'obs_value': 19.68909274117856, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing GIN...
# Data for GIN: {'iso3': 'GIN', 'time_period': 2022, 'obs_value': 20.6360953235589, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing GUY...
# Data for GUY: {'iso3': 'GUY', 'time_period': 2022, 'obs_value': 83.47257783132905, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing HTI...
# Data for HTI: {'iso3': 'HTI', 'time_period': 2022, 'obs_value': 22.58268496619633, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing xPI...
# Failed to fetch data for xPI. HTTP Status: 404
# No data found for xPI
# Processing HMD...
# Failed to fetch data for HMD. HTTP Status: 404
# No data found for HMD
# Processing VAT...
# Failed to fetch data for VAT. HTTP Status: 404
# No data found for VAT
# Processing HND...
# Data for HND: {'iso3': 'HND', 'time_period': 2022, 'obs_value': 84.96356058475281, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing HUN...
# Failed to fetch data for HUN. HTTP Status: 404
# No data found for HUN
# Processing ISL...
# Failed to fetch data for ISL. HTTP Status: 404
# No data found for ISL
# Processing IRN...
# Failed to fetch data for IRN. HTTP Status: 404
# No data found for IRN
# Processing IRQ...
# Data for IRQ: {'iso3': 'IRQ', 'time_period': 2022, 'obs_value': 97.3916076752442, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing IRL...
# Failed to fetch data for IRL. HTTP Status: 404
# No data found for IRL
# Processing IMN...
# Failed to fetch data for IMN. HTTP Status: 404
# No data found for IMN
# Processing ISR...
# Failed to fetch data for ISR. HTTP Status: 404
# No data found for ISR
# Processing ITA...
# Failed to fetch data for ITA. HTTP Status: 404
# No data found for ITA
# Processing JAM...
# Data for JAM: {'iso3': 'JAM', 'time_period': 2015, 'obs_value': 66.64750462692352, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing JPN...
# Failed to fetch data for JPN. HTTP Status: 404
# No data found for JPN
# Processing MLT...
# Failed to fetch data for MLT. HTTP Status: 404
# No data found for MLT
# Processing JEY...
# Failed to fetch data for JEY. HTTP Status: 404
# No data found for JEY
# Processing JOR...
# Failed to fetch data for JOR. HTTP Status: 404
# No data found for JOR
# Processing KAZ...
# Data for KAZ: {'iso3': 'KAZ', 'time_period': 2019, 'obs_value': 99.00983066893131, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing KEN...
# Data for KEN: {'iso3': 'KEN', 'time_period': 2022, 'obs_value': 37.59923838718469, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing KIR...
# Data for KIR: {'iso3': 'KIR', 'time_period': 2022, 'obs_value': 55.68317546616041, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing xRI...
# Failed to fetch data for xRI. HTTP Status: 404
# No data found for xRI
# Processing KWT...
# Failed to fetch data for KWT. HTTP Status: 404
# No data found for KWT
# Processing KGZ...
# Data for KGZ: {'iso3': 'KGZ', 'time_period': 2022, 'obs_value': 99.84673682035216, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing LAO...
# Data for LAO: {'iso3': 'LAO', 'time_period': 2021, 'obs_value': 55.81001562347002, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing LVA...
# Failed to fetch data for LVA. HTTP Status: 404
# No data found for LVA
# Processing LBN...
# Failed to fetch data for LBN. HTTP Status: 404
# No data found for LBN
# Processing LSO...
# Data for LSO: {'iso3': 'LSO', 'time_period': 2022, 'obs_value': 5.571910566957082, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing LBR...
# Data for LBR: {'iso3': 'LBR', 'time_period': 2022, 'obs_value': 3.440188936066098, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing LBY...
# Failed to fetch data for LBY. HTTP Status: 404
# No data found for LBY
# Processing MHL...
# Data for MHL: {'iso3': 'MHL', 'time_period': 2021, 'obs_value': 85.09115835447193, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing MTQ...
# Failed to fetch data for MTQ. HTTP Status: 404
# No data found for MTQ
# Processing MRT...
# Data for MRT: {'iso3': 'MRT', 'time_period': 2022, 'obs_value': 41.75240870408469, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing MUS...
# Failed to fetch data for MUS. HTTP Status: 404
# No data found for MUS
# Processing PRY...
# Data for PRY: {'iso3': 'PRY', 'time_period': 2020, 'obs_value': 80.15306460143181, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing PER...
# Failed to fetch data for PER. HTTP Status: 404
# No data found for PER
# Processing xJK...
# Failed to fetch data for xJK. HTTP Status: 404
# No data found for xJK
# Processing LIE...
# Failed to fetch data for LIE. HTTP Status: 404
# No data found for LIE
# Processing LTU...
# Failed to fetch data for LTU. HTTP Status: 404
# No data found for LTU
# Processing LUX...
# Failed to fetch data for LUX. HTTP Status: 404
# No data found for LUX
# Processing MAC...
# Failed to fetch data for MAC. HTTP Status: 404
# No data found for MAC
# Processing MDG...
# Data for MDG: {'iso3': 'MDG', 'time_period': 2022, 'obs_value': 23.43563054150082, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing MYS...
# Failed to fetch data for MYS. HTTP Status: 404
# No data found for MYS
# Processing MDV...
# Data for MDV: {'iso3': 'MDV', 'time_period': 2021, 'obs_value': 95.83909850344104, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing MLI...
# Data for MLI: {'iso3': 'MLI', 'time_period': 2022, 'obs_value': 17.30086899161632, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing BLM...
# Failed to fetch data for BLM. HTTP Status: 404
# No data found for BLM
# Processing MYT...
# Failed to fetch data for MYT. HTTP Status: 404
# No data found for MYT
# Processing MEX...
# Data for MEX: {'iso3': 'MEX', 'time_period': 2022, 'obs_value': 93.94082133247163, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing FSM...
# Failed to fetch data for FSM. HTTP Status: 404
# No data found for FSM
# Processing MDA...
# Data for MDA: {'iso3': 'MDA', 'time_period': 2016, 'obs_value': 86.97941860436201, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing MCO...
# Failed to fetch data for MCO. HTTP Status: 404
# No data found for MCO
# Processing MNG...
# Data for MNG: {'iso3': 'MNG', 'time_period': 2022, 'obs_value': 86.37693432754767, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing MSR...
# Failed to fetch data for MSR. HTTP Status: 404
# No data found for MSR
# Processing MAR...
# Failed to fetch data for MAR. HTTP Status: 404
# No data found for MAR
# Processing MOZ...
# Data for MOZ: {'iso3': 'MOZ', 'time_period': 2015, 'obs_value': 12.22698368782973, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing NAM...
# Data for NAM: {'iso3': 'NAM', 'time_period': 2017, 'obs_value': 44.5999033093996, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing NRU...
# Failed to fetch data for NRU. HTTP Status: 404
# No data found for NRU
# Processing NPL...
# Data for NPL: {'iso3': 'NPL', 'time_period': 2022, 'obs_value': 63.54284190094649, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing NLD...
# Failed to fetch data for NLD. HTTP Status: 404
# No data found for NLD
# Processing NCL...
# Failed to fetch data for NCL. HTTP Status: 404
# No data found for NCL
# Processing NZL...
# Failed to fetch data for NZL. HTTP Status: 404
# No data found for NZL
# Processing NIC...
# Failed to fetch data for NIC. HTTP Status: 404
# No data found for NIC
# Processing NER...
# Data for NER: {'iso3': 'NER', 'time_period': 2022, 'obs_value': 24.61680629635114, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing NIU...
# Failed to fetch data for NIU. HTTP Status: 404
# No data found for NIU
# Processing NFK...
# Failed to fetch data for NFK. HTTP Status: 404
# No data found for NFK
# Processing MNP...
# Failed to fetch data for MNP. HTTP Status: 404
# No data found for MNP
# Processing NOR...
# Failed to fetch data for NOR. HTTP Status: 404
# No data found for NOR
# Processing OMN...
# Data for OMN: {'iso3': 'OMN', 'time_period': 2021, 'obs_value': 97.4, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing PAK...
# Data for PAK: {'iso3': 'PAK', 'time_period': 2022, 'obs_value': 84.69131223445912, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing PLW...
# Failed to fetch data for PLW. HTTP Status: 404
# No data found for PLW
# Processing PAN...
# Failed to fetch data for PAN. HTTP Status: 404
# No data found for PAN
# Processing PCN...
# Failed to fetch data for PCN. HTTP Status: 404
# No data found for PCN
# Processing POL...
# Failed to fetch data for POL. HTTP Status: 404
# No data found for POL
# Processing PRT...
# Failed to fetch data for PRT. HTTP Status: 404
# No data found for PRT
# Processing PRI...
# Failed to fetch data for PRI. HTTP Status: 404
# No data found for PRI
# Processing QAT...
# Failed to fetch data for QAT. HTTP Status: 404
# No data found for QAT
# Processing KOR...
# Failed to fetch data for KOR. HTTP Status: 404
# No data found for KOR
# Processing ROU...
# Failed to fetch data for ROU. HTTP Status: 404
# No data found for ROU
# Processing REU...
# Failed to fetch data for REU. HTTP Status: 404
# No data found for REU
# Processing SHN...
# Failed to fetch data for SHN. HTTP Status: 404
# No data found for SHN
# Processing SPM...
# Failed to fetch data for SPM. HTTP Status: 404
# No data found for SPM
# Processing KNA...
# Failed to fetch data for KNA. HTTP Status: 404
# No data found for KNA
# Processing LCA...
# Data for LCA: {'iso3': 'LCA', 'time_period': 2016, 'obs_value': 87.33164756387296, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing VCT...
# Failed to fetch data for VCT. HTTP Status: 404
# No data found for VCT
# Processing WSM...
# Data for WSM: {'iso3': 'WSM', 'time_period': 2022, 'obs_value': 71.96436810144188, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing TKL...
# Failed to fetch data for TKL. HTTP Status: 404
# No data found for TKL
# Processing TON...
# Data for TON: {'iso3': 'TON', 'time_period': 2022, 'obs_value': 69.54366217489338, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing SMR...
# Failed to fetch data for SMR. HTTP Status: 404
# No data found for SMR
# Processing STP...
# Data for STP: {'iso3': 'STP', 'time_period': 2022, 'obs_value': 58.05790840278117, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing SAU...
# Failed to fetch data for SAU. HTTP Status: 404
# No data found for SAU
# Processing xSR...
# Failed to fetch data for xSR. HTTP Status: 404
# No data found for xSR
# Processing xSK...
# Failed to fetch data for xSK. HTTP Status: 404
# No data found for xSK
# Processing SYC...
# Failed to fetch data for SYC. HTTP Status: 404
# No data found for SYC
# Processing SLE...
# Data for SLE: {'iso3': 'SLE', 'time_period': 2022, 'obs_value': 17.83658224268026, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing SGP...
# Failed to fetch data for SGP. HTTP Status: 404
# No data found for SGP
# Processing SVK...
# Failed to fetch data for SVK. HTTP Status: 404
# No data found for SVK
# Processing SVN...
# Failed to fetch data for SVN. HTTP Status: 404
# No data found for SVN
# Processing SLB...
# Data for SLB: {'iso3': 'SLB', 'time_period': 2019, 'obs_value': 38.63639296775894, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing SOM...
# Data for SOM: {'iso3': 'SOM', 'time_period': 2022, 'obs_value': 25.0976401225684, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing ZAF...
# Data for ZAF: {'iso3': 'ZAF', 'time_period': 2020, 'obs_value': 44.36969324858509, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing SGS...
# Failed to fetch data for SGS. HTTP Status: 404
# No data found for SGS
# Processing ESP...
# Failed to fetch data for ESP. HTTP Status: 404
# No data found for ESP
# Processing xSI...
# Failed to fetch data for xSI. HTTP Status: 404
# No data found for xSI
# Processing LKA...
# Data for LKA: {'iso3': 'LKA', 'time_period': 2022, 'obs_value': 85.3463323653096, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing SUR...
# Data for SUR: {'iso3': 'SUR', 'time_period': 2022, 'obs_value': 72.11623284522237, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing SJM...
# Failed to fetch data for SJM. HTTP Status: 404
# No data found for SJM
# Processing SWZ...
# Data for SWZ: {'iso3': 'SWZ', 'time_period': 2020, 'obs_value': 24.3110733978139, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing SWE...
# Failed to fetch data for SWE. HTTP Status: 404
# No data found for SWE
# Processing CHE...
# Failed to fetch data for CHE. HTTP Status: 404
# No data found for CHE
# Processing SYR...
# Data for SYR: {'iso3': 'SYR', 'time_period': 2022, 'obs_value': 84.41615089426561, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing TJK...
# Data for TJK: {'iso3': 'TJK', 'time_period': 2022, 'obs_value': 72.95356280951715, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing THA...
# Data for THA: {'iso3': 'THA', 'time_period': 2022, 'obs_value': 85.01881918111813, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing MKD...
# Data for MKD: {'iso3': 'MKD', 'time_period': 2022, 'obs_value': 99.67284695384332, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing TLS...
# Data for TLS: {'iso3': 'TLS', 'time_period': 2020, 'obs_value': 28.40752953901305, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing TGO...
# Data for TGO: {'iso3': 'TGO', 'time_period': 2022, 'obs_value': 17.33833398232859, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing TTO...
# Data for TTO: {'iso3': 'TTO', 'time_period': 2015, 'obs_value': 90.06344254796788, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing xFR...
# Failed to fetch data for xFR. HTTP Status: 404
# No data found for xFR
# Processing TUR...
# Failed to fetch data for TUR. HTTP Status: 404
# No data found for TUR
# Processing TKM...
# Data for TKM: {'iso3': 'TKM', 'time_period': 2022, 'obs_value': 100.0, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing TUV...
# Data for TUV: {'iso3': 'TUV', 'time_period': 2022, 'obs_value': 93.95666850431674, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing UKR...
# Failed to fetch data for UKR. HTTP Status: 404
# No data found for UKR
# Processing ARE...
# Failed to fetch data for ARE. HTTP Status: 404
# No data found for ARE
# Processing GBR...
# Failed to fetch data for GBR. HTTP Status: 404
# No data found for GBR
# Processing VIR...
# Failed to fetch data for VIR. HTTP Status: 404
# No data found for VIR
# Processing USA...
# Failed to fetch data for USA. HTTP Status: 404
# No data found for USA
# Processing URY...
# Failed to fetch data for URY. HTTP Status: 404
# No data found for URY
# Processing UZB...
# Data for UZB: {'iso3': 'UZB', 'time_period': 2022, 'obs_value': 81.62646596045505, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing VNM...
# Data for VNM: {'iso3': 'VNM', 'time_period': 2022, 'obs_value': 88.71177477073984, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing WLF...
# Failed to fetch data for WLF. HTTP Status: 404
# No data found for WLF
# Processing ESH...
# Failed to fetch data for ESH. HTTP Status: 404
# No data found for ESH
# Processing YEM...
# Data for YEM: {'iso3': 'YEM', 'time_period': 2017, 'obs_value': 48.61296825965573, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing ZWE...
# Data for ZWE: {'iso3': 'ZWE', 'time_period': 2022, 'obs_value': 42.45609381262432, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing IDN...
# Data for IDN: {'iso3': 'IDN', 'time_period': 2022, 'obs_value': 78.98522121582404, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing MMR...
# Data for MMR: {'iso3': 'MMR', 'time_period': 2022, 'obs_value': 74.58558431110781, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing PNG...
# Data for PNG: {'iso3': 'PNG', 'time_period': 2022, 'obs_value': 29.85549829393217, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing PHL...
# Data for PHL: {'iso3': 'PHL', 'time_period': 2022, 'obs_value': 81.75091888258561, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing FJI...
# Data for FJI: {'iso3': 'FJI', 'time_period': 2022, 'obs_value': 86.52844162599865, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing VUT...
# Data for VUT: {'iso3': 'VUT', 'time_period': 2022, 'obs_value': 75.87976670830339, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing SEN...
# Data for SEN: {'iso3': 'SEN', 'time_period': 2022, 'obs_value': 22.24600594674569, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing CUB...
# Data for CUB: {'iso3': 'CUB', 'time_period': 2022, 'obs_value': 93.37921726961034, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing SDN...
# Data for SDN: {'iso3': 'SDN', 'time_period': 2022, 'obs_value': 10.76258197636571, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing HKG...
# Failed to fetch data for HKG. HTTP Status: 404
# No data found for HKG
# Processing EGY...
# Data for EGY: {'iso3': 'EGY', 'time_period': 2020, 'obs_value': 89.83093199421974, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing SSD...
# Data for SSD: {'iso3': 'SSD', 'time_period': 2022, 'obs_value': 5.6, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing TWN...
# Failed to fetch data for TWN. HTTP Status: 404
# No data found for TWN
# Processing CUW...
# Failed to fetch data for CUW. HTTP Status: 404
# No data found for CUW
# Processing DMA...
# Failed to fetch data for DMA. HTTP Status: 404
# No data found for DMA
# Processing ALA...
# Failed to fetch data for ALA. HTTP Status: 404
# No data found for ALA
# Processing BES...
# Failed to fetch data for BES. HTTP Status: 404
# No data found for BES
# Processing MAF...
# Failed to fetch data for MAF. HTTP Status: 404
# No data found for MAF
# Processing PSE...
# Data for PSE: {'iso3': 'PSE', 'time_period': 2022, 'obs_value': 94.91776940200549, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing SXM...
# Failed to fetch data for SXM. HTTP Status: 404
# No data found for SXM
# Processing MNE...
# Data for MNE: {'iso3': 'MNE', 'time_period': 2022, 'obs_value': 99.24174172882446, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing SRB...
# Data for SRB: {'iso3': 'SRB', 'time_period': 2014, 'obs_value': 98.13012009951635, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing xJL...
# Failed to fetch data for xJL. HTTP Status: 404
# No data found for xJL
# Processing xUK...
# Failed to fetch data for xUK. HTTP Status: 404
# No data found for xUK
# Processing TUN...
# Data for TUN: {'iso3': 'TUN', 'time_period': 2022, 'obs_value': 84.26921346741088, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing RUS...
# Failed to fetch data for RUS. HTTP Status: 404
# No data found for RUS
# Processing COL...
# Data for COL: {'iso3': 'COL', 'time_period': 2022, 'obs_value': 70.1535998009368, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing RWA...
# Data for RWA: {'iso3': 'RWA', 'time_period': 2022, 'obs_value': 18.40200784759383, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing TZA...
# Data for TZA: {'iso3': 'TZA', 'time_period': 2022, 'obs_value': 28.91653310099642, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing COD...
# Data for COD: {'iso3': 'COD', 'time_period': 2022, 'obs_value': 19.35247042167662, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing UGA...
# Data for UGA: {'iso3': 'UGA', 'time_period': 2022, 'obs_value': 30.90419968059178, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing MWI...
# Data for MWI: {'iso3': 'MWI', 'time_period': 2022, 'obs_value': 15.30758864090309, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing ZMB...
# Data for ZMB: {'iso3': 'ZMB', 'time_period': 2022, 'obs_value': 18.15461533034629, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing CMR...
# Data for CMR: {'iso3': 'CMR', 'time_period': 2022, 'obs_value': 36.71183430031442, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing TCD...
# Data for TCD: {'iso3': 'TCD', 'time_period': 2022, 'obs_value': 26.20047319559801, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing CAF...
# Data for CAF: {'iso3': 'CAF', 'time_period': 2022, 'obs_value': 22.17641402503165, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing COG...
# Data for COG: {'iso3': 'COG', 'time_period': 2019, 'obs_value': 48.18577994718563, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing NGA...
# Data for NGA: {'iso3': 'NGA', 'time_period': 2022, 'obs_value': 31.07882868506908, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing BEN...
# Data for BEN: {'iso3': 'BEN', 'time_period': 2022, 'obs_value': 12.13046401251178, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing COM...
# Data for COM: {'iso3': 'COM', 'time_period': 2016, 'obs_value': 15.57353329827459, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Processing IND...
# Data for IND: {'iso3': 'IND', 'time_period': 2022, 'obs_value': 76.26479312890172, 'data_source': 'WHO/UNICEF Joint Monitoring Programme (2024)'}
# Data successfully exported to /content/drive/MyDrive/CCRI/pillar2/P2_basic_hygiene.csv
